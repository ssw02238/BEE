# %%
# 임원 내 여성 비율 

import requests
import json
import openpyxl as xl

wb = xl.load_workbook('C:/Users/dpcks/고유번호추가.xlsx')
ws = wb.active;
cnt=-1
nono=0
ent=[]
for a in range(2,202):
    corp_code = ws.cell(row = a, column = 8).value
    res = requests.get("https://opendart.fss.or.kr/api/exctvSttus.json?crtfc_key=396b64cf35cf2138bbee974d47ca9d07baccc3e0&corp_code="+corp_code+"&bsns_year=2020&reprt_code=11011")

    cnt+=1
    item = json.loads(res.text)

    if item['status'] == '000':
        n = len(item['list'])
        cnt_man, cnt_woman = 0, 0
        for i in range(n):
                target = item['list'][i]
                if target['sexdstn'] == '남':
                    cnt_man += 1
                else:
                    cnt_woman += 1
    elif item['status'] == '013':
        nono+=1
        print("데이터 없음 ㅠㅠㅋㅋ")
    print("----------------------------")    
    print('남자 임원 수: ', cnt_man, '여자 임원 수: ', cnt_woman)
    # 비율 구하기 
    score1 = cnt_woman / (cnt_man + cnt_woman)
    print('여성 임원 비율: ', round(score1,3))
    ## 만점 10점 가정 
    print('******점수 ',cnt,'번', round(score1*2*10, 3))

    ent.append(round(score1,3))
print(nono)
print("여성 임원 비율 최대값 : ", max(ent))
print("여성 임원 비율 최소값 : ", min(ent))
# Out:
# ----------------------------
# 남자 임원 수:  9 여자 임원 수:  2
# 여성 임원 비율:  0.182
# ******점수  0 번 3.636
# ----------------------------
# 남자 임원 수:  8 여자 임원 수:  1
# 여성 임원 비율:  0.111
# ******점수  1 번 2.222
# ----------------------------
# 남자 임원 수:  6 여자 임원 수:  1
# 여성 임원 비율:  0.143
# ******점수  2 번 2.857
# ----------------------------
# 남자 임원 수:  5 여자 임원 수:  2
# 여성 임원 비율:  0.286
# ******점수  3 번 5.714
# ----------------------------
# 남자 임원 수:  6 여자 임원 수:  1
# 여성 임원 비율:  0.143
# ******점수  4 번 2.857
# ----------------------------
# 남자 임원 수:  105 여자 임원 수:  7
# 여성 임원 비율:  0.062
# ******점수  5 번 1.25
# ----------------------------
# 남자 임원 수:  89 여자 임원 수:  7
# 여성 임원 비율:  0.073
# ******점수  6 번 1.458
# ----------------------------
# 남자 임원 수:  10 여자 임원 수:  0
# 여성 임원 비율:  0.0
# ******점수  7 번 0.0
# ----------------------------
# 남자 임원 수:  43 여자 임원 수:  6
# 여성 임원 비율:  0.122
# ******점수  8 번 2.449
# ----------------------------
# 남자 임원 수:  9 여자 임원 수:  0
# 여성 임원 비율:  0.0
# ******점수  9 번 0.0
# ----------------------------
# 남자 임원 수:  12 여자 임원 수:  0
# 여성 임원 비율:  0.0
# ******점수  10 번 0.0
# ----------------------------
# 남자 임원 수:  96 여자 임원 수:  0
# 여성 임원 비율:  0.0
# ******점수  11 번 0.0
# ----------------------------
# 남자 임원 수:  8 여자 임원 수:  1
# 여성 임원 비율:  0.111
# ******점수  12 번 2.222
# ----------------------------
# 남자 임원 수:  310 여자 임원 수:  7
# 여성 임원 비율:  0.022
# ******점수  13 번 0.442
# ----------------------------
# 남자 임원 수:  13 여자 임원 수:  2
# 여성 임원 비율:  0.133
# ******점수  14 번 2.667
# ----------------------------
# 남자 임원 수:  89 여자 임원 수:  7
# 여성 임원 비율:  0.073
# ******점수  15 번 1.458
# ----------------------------
# 남자 임원 수:  7 여자 임원 수:  0
# 여성 임원 비율:  0.0
# ******점수  16 번 0.0
# ----------------------------
# 남자 임원 수:  7 여자 임원 수:  1
# 여성 임원 비율:  0.125
# ******점수  17 번 2.5
# ----------------------------
# 남자 임원 수:  32 여자 임원 수:  3
# 여성 임원 비율:  0.086
# ******점수  18 번 1.714
# ----------------------------
# 남자 임원 수:  23 여자 임원 수:  2
# 여성 임원 비율:  0.08
# ******점수  19 번 1.6
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\genericpath.py in exists(path)
#      18     try:
# ---> 19         os.stat(path)
#      20     except (OSError, ValueError):
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다: 'C:\\Users\\dpcks/.netrc'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-13e1c4908a4c> in <module>
#      12 for a in range(2,202):
#      13     corp_code = ws.cell(row = a, column = 8).value
# ---> 14     res = requests.get("https://opendart.fss.or.kr/api/exctvSttus.json?crtfc_key=396b64cf35cf2138bbee974d47ca9d07baccc3e0&corp_code="+corp_code+"&bsns_year=2020&reprt_code=11011")
#      15
#      16     cnt+=1
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     526             hooks=hooks,
#     527         )
# --> 528         prep = self.prepare_request(req)
#     529
#     530         proxies = proxies or {}
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in prepare_request(self, request)
#     451         auth = request.auth
#     452         if self.trust_env and not auth and not self.auth:
# --> 453             auth = get_netrc_auth(request.url)
#     454
#     455         p = PreparedRequest()
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\utils.py in get_netrc_auth(url, raise_errors)
#     190                 return
#     191
# --> 192             if os.path.exists(loc):
#     193                 netrc_path = loc
#     194                 break
#
# C:\ProgramData\Anaconda3\lib\genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except (OSError, ValueError):
#      21         return False
#
# KeyboardInterrupt:

# %%
# 임원 내 여성 비율 

import requests
import json
import openpyxl as xl

wb = xl.load_workbook('C:/Users/dpcks/고유번호추가.xlsx')
ws = wb.active;
cnt=-1
nono=0
ent=[]
for a in range(2,202):
    corp_code = ws.cell(row = a, column = 8).value
    res = requests.get("https://opendart.fss.or.kr/api/exctvSttus.json?crtfc_key=396b64cf35cf2138bbee974d47ca9d07baccc3e0&corp_code="+corp_code+"&bsns_year=2020&reprt_code=11011")

    cnt+=1
    item = json.loads(res.text)

    if item['status'] == '000':
        n = len(item['list'])
        cnt_man, cnt_woman = 0, 0
        for i in range(n):
                target = item['list'][i]
                if target['sexdstn'] == '남':
                    cnt_man += 1
                else:
                    cnt_woman += 1
    elif item['status'] == '013':
        nono+=1
    # 비율 구하기 
    score1 = cnt_woman / (cnt_man + cnt_woman)
    ## 만점 50점 가정 
    print(round(score1*2*10, 3)*5)
    ent.append(round(score1,3))
