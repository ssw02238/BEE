# %%
#특수 관계인 확인
import pandas as pd
from pandas import DataFrame
import requests
import pprint


#dart open api 인자
auth_key="2e915b536849f9c4f517c681d00833f8d83ac7ee" 
company_code=""


#excel 파일 읽기 (row : 200개)
xlsx = pd.read_excel('./corp_dataset.xlsx')
xlsx['largest shareholder'] = ''
#비율
trmend_posesn_stock_qota_rt = ''
for i in range(200):
    company_code = str(xlsx.code[i]).zfill(8)
    url = 'https://opendart.fss.or.kr/api/hyslrSttus.json?crtfc_key={}&corp_code={}&bsns_year=2020&reprt_code=11011'.format(auth_key, company_code)
    res = requests.get(url)
    data = res.json()
    # print(data)
    if data['status'] == '013':
        print('data가 없습니다.')
    else:
        share_list = data['list']
        # pprint.pprint(share_list)
        print('')
        
        largest = 0
        print(share_list[0]['corp_name'])
        for share in share_list:
            if share['stock_knd'] == '보통주' or '의결권 있는 주식' or '의결권있는 주식':
                if share['trmend_posesn_stock_qota_rt'] == '-':
                    ratio = 0
                else:
                    ratio = float(share['trmend_posesn_stock_qota_rt'])
                relative = share.get('relate')
                print('지분율 : {} 관계 :  {}'.format(ratio, relative))
# Out:
# 삼성전자
# 지분율 : 4.18 관계 :  최대주주 본인
# 지분율 : 0.27 관계 :  계열회사
# 지분율 : 0.09 관계 :  계열회사
# 지분율 : 1.49 관계 :  계열회사
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.08 관계 :  최대주주 본인
# 지분율 : 5.01 관계 :  계열회사
# 지분율 : 0.08 관계 :  출연 재단
# 지분율 : 0.03 관계 :  출연 재단
# 지분율 : 0.91 관계 :  최대주주의 배우자
# 지분율 : 0.7 관계 :  최대주주의 자
# 지분율 : 8.51 관계 :  계열회사
# 지분율 : 0.01 관계 :  계열회사
# 지분율 : 21.18 관계 :  None
# 지분율 : 0.17 관계 :  None
#
# SK하이닉스
# 지분율 : 20.07 관계 :  최대주주
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 20.07 관계 :  None
# 지분율 : 0 관계 :  None
#
# NAVER
# 지분율 : 0.0 관계 :  본인
# 지분율 : 11.56 관계 :  특수관계인
# 지분율 : 11.56 관계 :  None
# 지분율 : 0 관계 :  None
#
# 카카오
# 지분율 : 14.12 관계 :  본인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 11.22 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.07 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 25.47 관계 :  None
# 지분율 : 0 관계 :  None
#
# 삼성바이오로직스
# 지분율 : 43.44 관계 :  최대주주
# 지분율 : 31.49 관계 :  특수관계인
# 지분율 : 0.07 관계 :  특수관계인
# 지분율 : 0.07 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 75.08 관계 :  None
# 지분율 : 0 관계 :  None
#
# LG화학
# 지분율 : 30.06 관계 :  최대주주 본인
# 지분율 : 0.03 관계 :  (주)LG의 최대주주의 특수관계법인
# 지분율 : 0.0 관계 :  -
# 지분율 : 0.0 관계 :  -
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 30.09 관계 :  None
# 지분율 : 0.0 관계 :  None
# 지분율 : 30.09 관계 :  None
#
# 삼성SDI
# 지분율 : 19.58 관계 :  최대주주 본인
# 지분율 : 0.0 관계 :  계열회사 (SDI) 임원
# 지분율 : 0.14 관계 :  계열회사
# 지분율 : 0.14 관계 :  계열회사
# 지분율 : 0.58 관계 :  재단
# 지분율 : 0.25 관계 :  재단
# 지분율 : 0.01 관계 :  계열회사 (SDI) 임원
# 지분율 : 0.0 관계 :  계열회사 (SDI) 임원
# 지분율 : 0.0 관계 :  계열회사 (SDI) 임원
# 지분율 : 0.0 관계 :  계열회사 (SDI) 임원
# 지분율 : 20.56 관계 :  None
# 지분율 : 0.14 관계 :  None
#
# 현대자동차
# 지분율 : 21.43 관계 :  본인
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 5.33 관계 :  임원
# 지분율 : 0.0 관계 :  임원(정몽구)의 직계비속
# 지분율 : 0.0 관계 :  임원(정몽구)의 직계비속
# 지분율 : 0.0 관계 :  임원(정몽구)의 직계비속
# 지분율 : 0.0 관계 :  임원(정몽구)의 직계비속
# 지분율 : 2.62 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 29.38 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# 셀트리온
# 지분율 : 20.02 관계 :  본인
# 지분율 : 0.02 관계 :  계열회사 임원
# 지분율 : 0.02 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 2.12 관계 :  계열회사
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.1 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.08 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.05 관계 :  임원
# 지분율 : 0.04 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.03 관계 :  임원
# 지분율 : 0.03 관계 :  계열회사 임원
# 지분율 : 22.68 관계 :  None
# 지분율 : 0 관계 :  None
#
# 기아
# 지분율 : 33.88 관계 :  최대주주
# 지분율 : 1.74 관계 :  임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 35.62 관계 :  None
# 지분율 : 0 관계 :  None
#
# 포스코
# 지분율 : 11.75 관계 :  최대주주본인
# 지분율 : 11.75 관계 :  None
# 지분율 : 0 관계 :  None
#
# 현대모비스
# 지분율 : 17.28 관계 :  최대주주
# 지분율 : 7.13 관계 :  계열회사 임원
# 지분율 : 5.79 관계 :  계열회사
# 지분율 : 0.69 관계 :  계열회사
# 지분율 : 0.32 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 31.22 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# 삼성물산
# 지분율 : 17.33 관계 :  최대주주 본인
# 지분율 : 2.88 관계 :  친인척
# 지분율 : 5.55 관계 :  친인척
# 지분율 : 5.55 관계 :  친인척
# 지분율 : 0.32 관계 :  친인척
# 지분율 : 0.61 관계 :  계열비영리법인
# 지분율 : 0.04 관계 :  계열비영리법인
# 지분율 : 1.06 관계 :  계열비영리법인
# 지분율 : 0.08 관계 :  계열회사
# 지분율 : 33.42 관계 :  None
# 지분율 : 0 관계 :  None
# 지분율 : 33.42 관계 :  None
#
# LG전자
# 지분율 : 33.67 관계 :  최대주주 본인
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 33.67 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# SK바이오사이언스
# 지분율 : 98.04 관계 :  최대주주
# 지분율 : 98.04 관계 :  None
# 지분율 : 0 관계 :  None
#
# SK이노베이션
# 지분율 : 33.4 관계 :  본인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 33.41 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# LG생활건강
# 지분율 : 34.03 관계 :  최대주주 본인
# 지분율 : 0.48 관계 :  계열회사 임원
# 지분율 : 34.03 관계 :  None
# 지분율 : 0.48 관계 :  None
#
# SK텔레콤
# 지분율 : 26.78 관계 :  본인
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 26.78 관계 :  None
# 지분율 : 0 관계 :  None
#
# KB금융
# 지분율 : 9.93 관계 :  본인 및 특별관계자
# 지분율 : 9.93 관계 :  None
# 지분율 : 0 관계 :  None
#
# 신한지주
# 지분율 : 9.81 관계 :  본인및특별관계자
# 지분율 : 0.0 관계 :  본인및특별관계자
# 지분율 : 9.81 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# SK
# 지분율 : 18.44 관계 :  최대주주
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.08 관계 :  특수관계인
# 지분율 : 0.74 관계 :  특수관계인
# 지분율 : 0.14 관계 :  특수관계인
# 지분율 : 0.14 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.2 관계 :  특수관계인
# 지분율 : 0.04 관계 :  특수관계인
# 지분율 : 0.04 관계 :  특수관계인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 6.85 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 2.36 관계 :  특수관계인
# 지분율 : 0.26 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 29.55 관계 :  None
# 지분율 : 0 관계 :  None
#
# HMM
# 지분율 : 12.61 관계 :  본인
# 지분율 : 4.27 관계 :  최대주주의특별관계자
# 지분율 : 16.88 관계 :  None
# 지분율 : 0 관계 :  None
#
# 한국전력공사
# 지분율 : 32.9 관계 :  최대주주
# 지분율 : 18.2 관계 :  특수관계인
# 지분율 : 51.1 관계 :  None
# 지분율 : 0 관계 :  None
#
# LG
# 지분율 : 15.95 관계 :  최대주주 본인
# 지분율 : 0.26 관계 :  최대주주의 친인척
# 지분율 : 0.0 관계 :  최대주주의 친인척
# 지분율 : 0.35 관계 :  최대주주의 친인척
# 지분율 : 0.08 관계 :  최대주주의 친인척
# 지분율 : 0.6 관계 :  최대주주의 친인척
# 지분율 : 0.28 관계 :  최대주주의 친인척
# 지분율 : 0.01 관계 :  최대주주의 친인척
# 지분율 : 0.07 관계 :  최대주주의 친인척
# 지분율 : 0.06 관계 :  최대주주의 친인척
# 지분율 : 0.72 관계 :  최대주주의 친인척
# 지분율 : 0.69 관계 :  최대주주의 친인척
# 지분율 : 4.2 관계 :  최대주주의 친인척
# 지분율 : 0.05 관계 :  최대주주의 친인척
# 지분율 : 0.0 관계 :  최대주주의 친인척
# 지분율 : 0.05 관계 :  최대주주의 친인척
# 지분율 : 0.03 관계 :  최대주주의 친인척
# 지분율 : 0.07 관계 :  최대주주의 친인척
# 지분율 : 0.63 관계 :  최대주주의 친인척
# 지분율 : 0.1 관계 :  최대주주의 친인척
# 지분율 : 0.31 관계 :  최대주주의 친인척
# 지분율 : 0.0 관계 :  최대주주의 친인척
# 지분율 : 0.18 관계 :  최대주주의 친인척
# 지분율 : 0.01 관계 :  ㈜LG 등기임원
# 지분율 : 0.33 관계 :  최대주주의 특수관계법인
# 지분율 : 2.13 관계 :  최대주주의 특수관계법인
# 지분율 : 3.05 관계 :  최대주주의 친인척
# 지분율 : 4.48 관계 :  최대주주의 친인척
# 지분율 : 0.03 관계 :  최대주주의 친인척
# 지분율 : 7.72 관계 :  최대주주의 친인척
# 지분율 : 2.92 관계 :  최대주주의 친인척
# 지분율 : 0.72 관계 :  최대주주의 친인척
# 지분율 : 46.06 관계 :  None
# 지분율 : 0 관계 :  None
#
# 삼성생명
# 지분율 : 20.76 관계 :  최대주주 본인
# 지분율 : 0.06 관계 :  최대주주의 직계비속
# 지분율 : 19.34 관계 :  최대주주의 계열회사
# 지분율 : 4.68 관계 :  최대주주의 계열비영리법인
# 지분율 : 2.18 관계 :  최대주주의 계열비영리법인
# 지분율 : 0.0 관계 :  최대주주의 계열회사 등기임원
# 지분율 : 0.0 관계 :  최대주주의 계열회사 등기임원
# 지분율 : 47.02 관계 :  None
# 지분율 : 0 관계 :  None
# data가 없습니다.
#
# 삼성전기
# 지분율 : 23.69 관계 :  최대주주 본인
# 지분율 : 0.01 관계 :  최대주주 계열회사의 임원
# (발행회사의 임원)
# 지분율 : 0.0 관계 :  최대주주 계열회사의 임원
# (발행회사의 임원)
# 지분율 : 0.0 관계 :  최대주주 계열회사의 임원
# (발행회사의 임원)
# 지분율 : 0.0 관계 :  최대주주 계열회사의 사외이사
# (발행회사의 사외이사)
# 지분율 : 0.23 관계 :  최대주주 계열회사
# 지분율 : 1.01 관계 :  최대주주 계열회사
# 지분율 : 23.93 관계 :  None
# 지분율 : 1.01 관계 :  None
#
# 엔씨소프트
# 지분율 : 11.97 관계 :  최대주주 (본인)
# 지분율 : 0.0 관계 :  최대주주의 특수관계인
# 지분율 : 0.0 관계 :  최대주주의 특수관계인
# 지분율 : 0.01 관계 :  최대주주의 특수관계인
# 지분율 : 0.0 관계 :  최대주주의 특수관계인
# 지분율 : 0.0 관계 :  최대주주의 특수관계인
# 지분율 : 0.0 관계 :  최대주주의 특수관계인
# 지분율 : 0.0 관계 :  최대주주의 특수관계인
# 지분율 : 0.0 관계 :  최대주주의 특수관계인
# 지분율 : 0.0 관계 :  최대주주의 특수관계인
# 지분율 : 12.0 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# 삼성에스디에스
# 지분율 : 22.58 관계 :  본인
# 지분율 : 0.0 관계 :  계열회사 임원
#  (삼성에스디에스)
# 지분율 : 0.0 관계 :  계열회사 임원
#  (삼성에스디에스)
# 지분율 : 17.08 관계 :  계열회사
# 지분율 : 0.08 관계 :  계열회사
# 지분율 : 0.01 관계 :  최대주주
# 지분율 : 9.2 관계 :  최대주주의 자
# 지분율 : 3.9 관계 :  계열회사 임원
#  (호텔신라)
# 지분율 : 3.9 관계 :  출연재단 임원
#  (삼성복지재단)
# 지분율 : 0.0 관계 :  계열회사 임원
#  (삼성에스디에스)
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 56.75 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# 하나금융지주
# 지분율 : 9.88 관계 :  본인 및 특수관계인
# 지분율 : 9.88 관계 :  None
# 지분율 : 0 관계 :  None
# 아모레퍼시픽
# 지분율 : 37.13 관계 :  계열회사
# 지분율 : 14.31 관계 :  계열회사
# 지분율 : 10.72 관계 :  발행회사 임원, 계열회사 임원
# 지분율 : 0.25 관계 :  친인척
# 지분율 : 1.19 관계 :  재단
# 지분율 : 0.66 관계 :  재단
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 49.29 관계 :  None
# 지분율 : 14.97 관계 :  None
# 지분율 : 44.04 관계 :  None
#
# 포스코케미칼
# 지분율 : 61.26 관계 :  최대주주
# 지분율 : 3.38 관계 :  특수관계
# 지분율 : 0.01 관계 :  대표이사 사장
# 지분율 : 0.0 관계 :  사내이사
# 지분율 : 0.0 관계 :  상임감사
# 지분율 : 64.65 관계 :  None
# 지분율 : 0 관계 :  None
#
# 케이티앤지
# 지분율 : 11.52 관계 :  본인
# 지분율 : 11.52 관계 :  None
# 지분율 : 0 관계 :  None
#
# 하이브
# 지분율 : 34.7 관계 :  최대주주
# 지분율 : 0.0 관계 :  계열회사
# 등기임원
# 지분율 : 0.0 관계 :  계열회사
# 등기임원
# 지분율 : 34.8 관계 :  None
# 지분율 : 0 관계 :  None
#
# 두산중공업
# 지분율 : 41.95 관계 :  본인
# 지분율 : 0.05 관계 :  특수관계인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.05 관계 :  특수관계인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.04 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.1 관계 :  특수관계인
# 지분율 : 0.04 관계 :  특수관계인
# 지분율 : 0.07 관계 :  특수관계인
# 지분율 : 0.07 관계 :  특수관계인
# 지분율 : 42.47 관계 :  None
# 지분율 : 0 관계 :  None
#
# 대한항공
# 지분율 : 29.27 관계 :  본인
# 지분율 : 0.53 관계 :  기타
# 지분율 : 0.0 관계 :  기타
# 지분율 : 0.0 관계 :  기타
# 지분율 : 0.0 관계 :  기타
# 지분율 : 1.49 관계 :  재단
# 지분율 : 0.62 관계 :  재단
# 지분율 : 0.11 관계 :  재단
# 지분율 : 0.23 관계 :  재단
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.86 관계 :  본인
# 지분율 : 0.01 관계 :  임원
# 지분율 : 0.53 관계 :  임원
# 지분율 : 0.01 관계 :  계열사 임원
# 지분율 : 0.8 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  기타
# 지분율 : 0.53 관계 :  기타
# 지분율 : 0.01 관계 :  기타
# 지분율 : 31.13 관계 :  None
# 지분율 : 3.89 관계 :  None
#
# 넷마블
# 지분율 : 24.15 관계 :  최대주주
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 24.18 관계 :  None
# 지분율 : 0 관계 :  None
#
# 삼성화재해상보험
# 지분율 : 14.98 관계 :  최대주주 본인
# 지분율 : 0.0 관계 :  최대주주의 계열회사 등기임원
# 지분율 : 0.02 관계 :  최대주주 본인
# 지분율 : 1.53 관계 :  최대주주 본인
# 지분율 : 3.06 관계 :  최대주주의 계열 비영리법인
# 지분율 : 0.36 관계 :  최대주주의 계열 비영리법인
# 지분율 : 0.09 관계 :  사실상의 영향력을 행사하고 있는 개인
# 지분율 : 0.0 관계 :  최대주주의 계열회사 등기임원
# 지분율 : 0.0 관계 :  최대주주의 계열회사 등기임원
# 지분율 : 0.0 관계 :  최대주주의 계열회사 등기임원
# 지분율 : 18.5 관계 :  None
# 지분율 : 1.55 관계 :  None
#
# S-Oil
# 지분율 : 63.41 관계 :  최대주주 본인
# 지분율 : 0.01 관계 :  계열회사 등기임원
# 지분율 : 0.0 관계 :  계열회사 등기임원
# 지분율 : 0.0 관계 :  계열회사 등기임원
# 지분율 : 0.01 관계 :  계열회사 등기임원
# 지분율 : 0.0 관계 :  계열회사 등기임원
# 지분율 : 0.0 관계 :  계열회사 등기임원
# 지분율 : 0.0 관계 :  계열회사 등기임원
# 지분율 : 0.0 관계 :  계열회사 등기임원
# 지분율 : 8.74 관계 :  최대주주 본인
# 지분율 : 0.0 관계 :  계열회사 등기임원
# 지분율 : 0.0 관계 :  계열회사 등기임원
# 지분율 : 0.0 관계 :  계열회사 등기임원
# 지분율 : 0.0 관계 :  계열회사 등기임원
# 지분율 : 0.0 관계 :  계열회사 등기임원
# 지분율 : 0.01 관계 :  계열회사 등기임원
# 지분율 : 0.01 관계 :  계열회사 등기임원
# 지분율 : 63.45 관계 :  None
# 지분율 : 8.74 관계 :  None
#
# 고려아연
# 지분율 : 27.49 관계 :  본인
# 지분율 : 0.57 관계 :  출자자
# 지분율 : 0.85 관계 :  출자자
# 지분율 : 0.01 관계 :  출자자
# 지분율 : 0.01 관계 :  출자자
# 지분율 : 0.01 관계 :  출자자
# 지분율 : 0.03 관계 :  출자자
# 지분율 : 0.01 관계 :  출자자
# 지분율 : 1.59 관계 :  출자자
# 지분율 : 0.0 관계 :  출자자
# 지분율 : 0.01 관계 :  출자자
# 지분율 : 3.83 관계 :  임원
# 지분율 : 0.01 관계 :  출자자
# 지분율 : 0.9 관계 :  출자자
# 지분율 : 0.14 관계 :  출자자
# 지분율 : 0.29 관계 :  출자자
# 지분율 : 0.0 관계 :  출자자
# 지분율 : 0.0 관계 :  출자자
# 지분율 : 0.0 관계 :  출자자
# 지분율 : 1.76 관계 :  출자자
# 지분율 : 0.04 관계 :  출자자
# 지분율 : 0.2 관계 :  출자자
# 지분율 : 0.13 관계 :  임원
# 지분율 : 0.18 관계 :  출자자
# 지분율 : 1.65 관계 :  출자자
# 지분율 : 0.13 관계 :  출자자
# 지분율 : 0.05 관계 :  출자자
# 지분율 : 0.13 관계 :  출자자
# 지분율 : 0.21 관계 :  출자자
# 지분율 : 0.04 관계 :  출자단체
# 지분율 : 0.99 관계 :  피지배회사
# 지분율 : 1.56 관계 :  피지배회사
# 지분율 : 0.11 관계 :  피지배회사
# 지분율 : 0.39 관계 :  출자자
# 지분율 : 0.29 관계 :  출자단체
# 지분율 : 0.08 관계 :  출자자
# 지분율 : 0.41 관계 :  출자자
# 지분율 : 0.38 관계 :  출자자
# 지분율 : 0.02 관계 :  출자자
# 지분율 : 0.61 관계 :  출자자
# 지분율 : 0.06 관계 :  출자자
# 지분율 : 0.0 관계 :  출자자
# 지분율 : 0.21 관계 :  출자자
# 지분율 : 0.02 관계 :  출자자
# 지분율 : 1.82 관계 :  출자자
# 지분율 : 0.42 관계 :  출자자
# 지분율 : 0.18 관계 :  출자자
# 지분율 : 0.16 관계 :  출자자
# 지분율 : 0.02 관계 :  출자자
# 지분율 : 0.01 관계 :  출자자
# 지분율 : 0.01 관계 :  출자자
# 지분율 : 0.51 관계 :  출자자
# 지분율 : 48.53 관계 :  None
# 지분율 : 0 관계 :  None
#
# 에스케이바이오팜
# 지분율 : 75.0 관계 :  최대주주
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 75.0 관계 :  None
# 지분율 : 0 관계 :  None
#
# 한온시스템
# 지분율 : 50.5 관계 :  본인
# 지분율 : 50.5 관계 :  None
# 지분율 : 0 관계 :  None
#
# 케이티
# 지분율 : 11.68 관계 :  본인
# 지분율 : 11.68 관계 :  None
# 지분율 : 0 관계 :  None
#
# 롯데케미칼
# 지분율 : 25.33 관계 :  최대주주
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 20.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 9.3 관계 :  특수관계인
# 지분율 : 0.26 관계 :  특수관계인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 54.92 관계 :  None
# 지분율 : 0 관계 :  None
#
# 우리금융지주
# 지분율 : 17.25 관계 :  최대주주
# 지분율 : 17.25 관계 :  None
# 지분율 : 0 관계 :  None
#
# 한국조선해양
# 지분율 : 30.95 관계 :  최대주주
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 2.38 관계 :  특수관계인
# 지분율 : 0.61 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 33.96 관계 :  None
# 지분율 : 0 관계 :  None
# 지분율 : 33.96 관계 :  None
#
# 한화솔루션
# 지분율 : 37.25 관계 :  최대주주
# 지분율 : 0.16 관계 :  특수관계
# 지분율 : 0.01 관계 :  등기임원
# 지분율 : 0.01 관계 :  등기임원
# 지분율 : 0.0 관계 :  등기임원
# 지분율 : 0.0 관계 :  등기임원
# 지분율 : 0.0 관계 :  등기임원
# 지분율 : 37.42 관계 :  None
# 지분율 : 0 관계 :  None
#
# 기업은행
# 지분율 : 63.5 관계 :  최대주주
# 지분율 : 0.0 관계 :  최대주주
# 지분율 : 1.4 관계 :  최대주주의특수관계인
# 지분율 : 88.3 관계 :  최대주주의특수관계인
# 지분율 : 1.2 관계 :  최대주주의특수관계인
# 지분율 : 11.7 관계 :  최대주주의특수관계인
# 지분율 : 66.0 관계 :  None
# 지분율 : 100.0 관계 :  None
#
# LG디스플레이
# 지분율 : 37.9 관계 :  최대주주 본인
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 37.91 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# 현대글로비스
# 지분율 : 23.29 관계 :  최대주주
# 지분율 : 6.71 관계 :  친인척
# 지분율 : 4.88 관계 :  계열회사
# 지분율 : 4.46 관계 :  재단
# 지분율 : 11.0 관계 :  공동보유자
# 지분율 : 0.01 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 50.35 관계 :  None
# 지분율 : 0 관계 :  None
#
# 현대제철
# 지분율 : 17.27 관계 :  본 인
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 6.87 관계 :  계열회사
# 지분율 : 11.81 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 35.97 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# CJ제일제당
# 지분율 : 40.94 관계 :  최대주주
# 지분율 : 0.43 관계 :  특수관계인
# 지분율 : 0.03 관계 :  임원
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.13 관계 :  특수관계인
# 지분율 : 0.19 관계 :  특수관계인
# 지분율 : 0.05 관계 :  특수관계인
# 지분율 : 0.0 관계 :  임원
# 지분율 : 41.81 관계 :  None
# 지분율 : 0 관계 :  None
#
# LG유플러스
# 지분율 : 37.66 관계 :  최대주주
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  본인
# 지분율 : 37.66 관계 :  None
# 지분율 : 0 관계 :  None
#
# 금호석유화학
# 지분율 : 6.69 관계 :  임원
# (친인척)
# 지분율 : 10.0 관계 :  본인
# 지분율 : 7.17 관계 :  임원
# (친인척)
# 지분율 : 0.98 관계 :  임원
# (친인척)
# 지분율 : 0.01 관계 :  발행회사
# 임원
# 지분율 : 0.0 관계 :  발행회사
# 임원
# 지분율 : 0.01 관계 :  계열회사
# 임원
# 지분율 : 0.0 관계 :  계열회사
# 임원
# 지분율 : 0.01 관계 :  계열회사
# 임원
# 지분율 : 24.87 관계 :  None
# 지분율 : 0 관계 :  None
# data가 없습니다.
#
# 현대건설
# 지분율 : 20.95 관계 :  최대주주
# 지분율 : 5.24 관계 :  계열회사
# 지분율 : 8.73 관계 :  계열회사
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 34.92 관계 :  None
# 지분율 : 0 관계 :  None
#
# 코웨이
# 지분율 : 0.0 관계 :  최대주주 본인
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 25.08 관계 :  최대주주 본인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.02 관계 :  발행회사 임원
# 지분율 : 0.01 관계 :  발행회사 임원
# 지분율 : 0.01 관계 :  발행회사 임원
# 지분율 : 25.11 관계 :  None
# 지분율 : 0 관계 :  None
#
# 한국타이어앤테크놀로지
# 지분율 : 30.67 관계 :  최대주주
# 지분율 : 0.01 관계 :  기타
# 지분율 : 0.01 관계 :  기타
# 지분율 : 0.01 관계 :  기타
# 지분율 : 0.01 관계 :  기타
# 지분율 : 0.64 관계 :  계열사
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 5.67 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 2.07 관계 :  발행회사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.65 관계 :  계열사 임원
# 지분율 : 0.71 관계 :  기타
# 지분율 : 2.72 관계 :  기타
# 지분율 : 0.03 관계 :  기타
# 지분율 : 0.02 관계 :  기타
# 지분율 : 0.01 관계 :  기타
# 지분율 : 43.24 관계 :  None
# 지분율 : 0 관계 :  None
#
# SKC
# 지분율 : 40.6 관계 :  본인
# 지분율 : 0.2 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.1 관계 :  특수관계인
# 지분율 : 0.2 관계 :  재단
# 지분율 : 41.2 관계 :  None
# 지분율 : 0 관계 :  None
# 미래에셋증권
# 지분율 : 23.98 관계 :  최대주주
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.04 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 3.89 관계 :  최대주주
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.04 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.02 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  발행회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.02 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.02 관계 :  발행회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.03 관계 :  기타
# 지분율 : 0.0 관계 :  기타
# 지분율 : 0.0 관계 :  기타
# 지분율 : 0.0 관계 :  기타
# 지분율 : 0.0 관계 :  기타
# 지분율 : 0.02 관계 :  발행회사 임원
# 지분율 : 0.05 관계 :  발행회사 임원
# 지분율 : 0.05 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 24.2 관계 :  None
# 지분율 : 4.13 관계 :  None
#
# LG이노텍
# 지분율 : 40.79 관계 :  최대주주
# 지분율 : 0.0 관계 :  임원
# 지분율 : 40.79 관계 :  None
# 지분율 : 0 관계 :  None
#
# 현대중공업지주
# 지분율 : 26.6 관계 :  최대주주
# 지분율 : 5.26 관계 :  특수관계인
# 지분율 : 1.92 관계 :  특수관계인
# 지분율 : 0.49 관계 :  특수관계인
# 지분율 : 0.06 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 34.34 관계 :  None
# 지분율 : 34.34 관계 :  None
#
# 한국금융지주
# 지분율 : 20.7 관계 :  최대주주 본인
# 지분율 : 0.01 관계 :  임원
# 지분율 : 20.7 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# 한미사이언스
# 지분율 : 34.27 관계 :  본인
# 지분율 : 2.18 관계 :  친인척
# 지분율 : 1.09 관계 :  친인척
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 1.08 관계 :  친인척
# 지분율 : 1.05 관계 :  친인척
# 지분율 : 1.05 관계 :  친인척
# 지분율 : 1.05 관계 :  친인척
# 지분율 : 1.05 관계 :  친인척
# 지분율 : 1.05 관계 :  친인척
# 지분율 : 1.05 관계 :  친인척
# 지분율 : 1.26 관계 :  친인척
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 0.02 관계 :  친인척
# 지분율 : 0.02 관계 :  친인척
# 지분율 : 0.01 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 6.43 관계 :  계열회사
# 지분율 : 3.65 관계 :  친인척
# 지분율 : 3.55 관계 :  친인척
# 지분율 : 3.14 관계 :  친인척
# 지분율 : 1.11 관계 :  친인척
# 지분율 : 1.11 관계 :  친인척
# 지분율 : 0.05 관계 :  친인척
# 지분율 : 1.14 관계 :  친인척
# 지분율 : 66.42 관계 :  None
# 지분율 : 0 관계 :  None
#
# 이마트
# 지분율 : 18.56 관계 :  최대주주 본인
# 지분율 : 10.0 관계 :  최대주주 친인척
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 28.56 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# 오리온
# 지분율 : 37.37 관계 :  본인
# 지분율 : 4.08 관계 :  임원
# 지분율 : 0.5 관계 :  임원
# 지분율 : 0.6 관계 :  친인척
# 지분율 : 1.23 관계 :  친인척
# 지분율 : 0.02 관계 :  임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 43.81 관계 :  None
# 지분율 : 43.81 관계 :  None
#
# 삼성엔지니어링
# 지분율 : 11.69 관계 :  최대주주
# 지분율 : 0.15 관계 :  계열회사
# 지분율 : 0.22 관계 :  계열회사
# 지분율 : 6.97 관계 :  계열회사
# 지분율 : 1.54 관계 :  특수관계인
# 지분율 : 0.06 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 20.65 관계 :  None
# 지분율 : 0 관계 :  None
#
# 아모레퍼시픽그룹
# 지분율 : 53.9 관계 :  최대주주 본인
# 지분율 : 0.55 관계 :  비영리법인/단체
# 지분율 : 2.77 관계 :  비영리법인/단체
# 지분율 : 1.44 관계 :  비영리법인/단체
# 지분율 : 0.29 관계 :  비영리법인/단체
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 27.74 관계 :  최대주주 본인
# 지분율 : 0.12 관계 :  친인척
# 지분율 : 0.06 관계 :  친인척
# 지분율 : 2.93 관계 :  친인척
# 지분율 : 1.04 관계 :  친인척
# 지분율 : 1.72 관계 :  비영리법인/단체
# 지분율 : 0.15 관계 :  비영리법인/단체
# 지분율 : 0.52 관계 :  비영리법인/단체
# 지분율 : 61.95 관계 :  None
# 지분율 : 31.29 관계 :  None
# 지분율 : 57.63 관계 :  None
#
# 녹십자
# 지분율 : 50.06 관계 :  최대주주
# 지분율 : 0.01 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  재단
# 지분율 : 0.44 관계 :  재단
# 지분율 : 0.0 관계 :  계열사
# 지분율 : 0.56 관계 :  임원
# 지분율 : 0.09 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.23 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 51.39 관계 :  None
# 지분율 : 0 관계 :  None
#
# 유한양행
# 지분율 : 15.61 관계 :  본인
# 지분율 : 0.04 관계 :  본인
# 지분율 : 0.04 관계 :  임원
# 지분율 : 15.66 관계 :  None
# 지분율 : 0.04 관계 :  None
#
# 한진칼
# 지분율 : 5.82 관계 :  본인
# 지분율 : 0.63 관계 :  친족
# 지분율 : 0.06 관계 :  친족
# 지분율 : 0.0 관계 :  친족
# 지분율 : 0.0 관계 :  친족
# 지분율 : 0.0 관계 :  친족
# 지분율 : 0.0 관계 :  친족
# 지분율 : 1.91 관계 :  재단
# 지분율 : 0.62 관계 :  재단
# 지분율 : 0.14 관계 :  재단
# 지분율 : 0.96 관계 :  재단
# 지분율 : 0.53 관계 :  본인
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 5.79 관계 :  친족
# 지분율 : 0.53 관계 :  친족
# 지분율 : 5.78 관계 :  친족
# 지분율 : 0.53 관계 :  친족
# 지분율 : 4.74 관계 :  친족
# 지분율 : 0.8 관계 :  친족
# 지분율 : 0.0 관계 :  친족
# 지분율 : 25.83 관계 :  None
# 지분율 : 3.03 관계 :  None
#
# 두산밥캣
# 지분율 : 51.05 관계 :  최대주주
# 본인
# 지분율 : 0.01 관계 :  계열회사
# 임원
# 지분율 : 0.0 관계 :  계열회사
# 임원
# 지분율 : 51.06 관계 :  None
# 지분율 : 0 관계 :  None
#
# 삼성증권
# 지분율 : 29.39 관계 :  최대주주
# 지분율 : 0.17 관계 :  최대주주
# 지분율 : 0.22 관계 :  최대주주의
# 계열비영리법인
# 지분율 : 0.01 관계 :  최대주주의
# 계열회사
# 등기임원
# 지분율 : 0.0 관계 :  최대주주의
# 계열회사
# 등기임원
# 지분율 : 0.0 관계 :  최대주주의
# 계열회사
# 등기임원
# 지분율 : 29.8 관계 :  None
# 지분율 : 0 관계 :  None
#
# DB손해보험
# 지분율 : 9.01 관계 :  본인
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 5.94 관계 :  친인척
# 지분율 : 3.15 관계 :  친인척
# 지분율 : 5.0 관계 :  기타 단체
# 지분율 : 0.1 관계 :  임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 23.21 관계 :  None
# 지분율 : 0 관계 :  None
#
# 쌍용씨앤이
# 지분율 : 77.68 관계 :  본인
# 지분율 : 0.01 관계 :  계열회사의
# 임원
# 지분율 : 0.01 관계 :  계열회사의
# 임원
# 지분율 : 0.0 관계 :  계열회사의
# 임원
# 지분율 : 0.01 관계 :  계열회사의
# 임원
# 지분율 : 0.0 관계 :  본인
# 지분율 : 0.09 관계 :  발행회사의
#  임원
# 지분율 : 0.04 관계 :  발행회사의
#  임원
# 지분율 : 0.03 관계 :  발행회사의
#  임원
# 지분율 : 0.03 관계 :  발행회사의
#  임원
# 지분율 : 0.03 관계 :  발행회사의
#  임원
# 지분율 : 0.02 관계 :  발행회사의
#  임원
# 지분율 : 0.02 관계 :  계열회사의
# 임원
# 지분율 : 77.98 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# 팬오션
# 지분율 : 54.7 관계 :  최대주주
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.01 관계 :  계열사
# 지분율 : 0.02 관계 :  계열사임원
# 지분율 : 0.01 관계 :  계열사임원
# 지분율 : 0.11 관계 :  계열사임원
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 0.01 관계 :  친인척
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.01 관계 :  계열사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.01 관계 :  계열사임원
# 지분율 : 0.01 관계 :  친인척
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.01 관계 :  계열사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 54.89 관계 :  None
# 지분율 : 0 관계 :  None
#
# 삼성카드
# 지분율 : 71.86 관계 :  최대주주
# 지분율 : 0.0 관계 :  최대주주의
# 계열회사
# 등기임원
# 지분율 : 0.0 관계 :  최대주주의
# 계열회사
# 등기임원
# 지분율 : 71.86 관계 :  None
# 지분율 : 0 관계 :  None
#
# GS
# 지분율 : 4.75 관계 :  최대주주
# 지분율 : 0.25 관계 :  특수관계인
# 지분율 : 2.04 관계 :  특수관계인
# 지분율 : 1.08 관계 :  특수관계인
# 지분율 : 0.45 관계 :  특수관계인
# 지분율 : 0.27 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 2.37 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 2.16 관계 :  특수관계인
# 지분율 : 0.28 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 2.26 관계 :  특수관계인
# 지분율 : 0.5 관계 :  특수관계인
# 지분율 : 0.33 관계 :  특수관계인
# 지분율 : 0.53 관계 :  특수관계인
# 지분율 : 5.26 관계 :  특수관계인
# 지분율 : 0.94 관계 :  특수관계인
# 지분율 : 0.14 관계 :  특수관계인
# 지분율 : 0.35 관계 :  특수관계인
# 지분율 : 0.53 관계 :  특수관계인
# 지분율 : 1.65 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.1 관계 :  특수관계인
# 지분율 : 0.36 관계 :  특수관계인
# 지분율 : 0.12 관계 :  특수관계인
# 지분율 : 0.27 관계 :  특수관계인
# 지분율 : 0.47 관계 :  특수관계인
# 지분율 : 0.77 관계 :  특수관계인
# 지분율 : 2.69 관계 :  특수관계인
# 지분율 : 0.27 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 1.37 관계 :  특수관계인
# 지분율 : 2.11 관계 :  특수관계인
# 지분율 : 0.75 관계 :  특수관계인
# 지분율 : 1.37 관계 :  특수관계인
# 지분율 : 0.83 관계 :  특수관계인
# 지분율 : 2.12 관계 :  특수관계인
# 지분율 : 0.6 관계 :  특수관계인
# 지분율 : 0.06 관계 :  특수관계인
# 지분율 : 0.67 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.12 관계 :  특수관계인
# 지분율 : 2.19 관계 :  특수관계인
# 지분율 : 1.62 관계 :  특수관계인
# 지분율 : 0.06 관계 :  특수관계인
# 지분율 : 0.54 관계 :  특수관계인
# 지분율 : 0.08 관계 :  특수관계인
# 지분율 : 0.32 관계 :  특수관계인
# 지분율 : 2.21 관계 :  특수관계인
# 지분율 : 1.79 관계 :  특수관계인
# 지분율 : 0.63 관계 :  특수관계인
# 지분율 : 1.41 관계 :  특수관계인
# 지분율 : 52.12 관계 :  None
# 지분율 : 0 관계 :  None
#
# 삼성중공업
# 지분율 : 15.98 관계 :  최대
# 주주
# 지분율 : 3.06 관계 :  특수
# 관계인
# 지분율 : 0.06 관계 :  "
# 지분율 : 2.16 관계 :  "
# 지분율 : 0.38 관계 :  "
# 지분율 : 0.13 관계 :  "
# 지분율 : 0.12 관계 :  "
# 지분율 : 0.0 관계 :  "
# 지분율 : 0.0 관계 :  "
# 지분율 : 21.89 관계 :  None
# 지분율 : 0 관계 :  None
#
# 케이씨씨
# 지분율 : 18.55 관계 :  본인
# 지분율 : 0.26 관계 :  혈족3촌
# 지분율 : 0.17 관계 :  혈족3촌
# 지분율 : 0.02 관계 :  혈족3촌
# 지분율 : 0.02 관계 :  혈족3촌
# 지분율 : 5.05 관계 :  혈족1촌
# 지분율 : 8.47 관계 :  혈족2촌
# 지분율 : 5.28 관계 :  혈족2촌
# 지분율 : 0.21 관계 :  혈족5촌
# 지분율 : 0.21 관계 :  혈족5촌
# 지분율 : 0.01 관계 :  배우자
# 지분율 : 0.62 관계 :  혈족1촌
# 지분율 : 0.62 관계 :  혈족1촌
# 지분율 : 39.51 관계 :  None
# 지분율 : 0 관계 :  None
#
# GS건설
# 지분율 : 8.78 관계 :  최대주주 본인
# 지분율 : 3.03 관계 :  6촌이내의 혈족
# 지분율 : 0.37 관계 :  6촌이내의 혈족
# 지분율 : 0.31 관계 :  6촌이내의 혈족
# 지분율 : 1.9 관계 :  6촌이내의 혈족
# 지분율 : 1.18 관계 :  6촌이내의 혈족
# 지분율 : 0.04 관계 :  6촌이내의 혈족
# 지분율 : 0.02 관계 :  6촌이내의 혈족
# 지분율 : 0.0 관계 :  4촌이내의 인척
# 지분율 : 1.49 관계 :  재단
# 지분율 : 0.03 관계 :  6촌이내의 혈족
# 지분율 : 1.65 관계 :  6촌이내의 혈족
# 지분율 : 1.98 관계 :  6촌이내의 혈족
# 지분율 : 0.35 관계 :  6촌이내의 혈족
# 지분율 : 0.03 관계 :  6촌이내의 혈족
# 지분율 : 3.76 관계 :  6촌이내의 혈족
# 지분율 : 0.54 관계 :  6촌이내의 혈족
# 지분율 : 0.04 관계 :  6촌이내의 혈족
# 지분율 : 25.5 관계 :  None
# 지분율 : 0 관계 :  None
#
# CJ대한통운
# 지분율 : 40.16 관계 :  본인
# 지분율 : 40.16 관계 :  None
# 지분율 : 0 관계 :  None
# 한미약품
# 지분율 : 41.39 관계 :  최대주주 본인
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  임원 및 계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 41.4 관계 :  None
# 지분율 : 0 관계 :  None
#
# 롯데지주
# 지분율 : 13.0 관계 :  최대주주
# 지분율 : 1.2 관계 :  특수관계인
# 지분율 : 0.1 관계 :  특수관계인
# 지분율 : 2.5 관계 :  특수관계인
# 지분율 : 1.5 관계 :  특수관계인
# 지분율 : 11.1 관계 :  특수관계인
# 지분율 : 4.8 관계 :  특수관계인
# 지분율 : 5.1 관계 :  특수관계인
# 지분율 : 3.9 관계 :  특수관계인
# 지분율 : 0.9 관계 :  특수관계인
# 지분율 : 0.8 관계 :  특수관계인
# 지분율 : 8.2 관계 :  최대주주
# 지분율 : 3.3 관계 :  특수관계인
# 지분율 : 6.2 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.1 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.9 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 3.5 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 3.2 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 5.1 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.1 관계 :  특수관계인
# 지분율 : 42.6 관계 :  None
# 지분율 : 33.1 관계 :  None
#
# 신풍제약
# 지분율 : 27.97 관계 :  본인
# 지분율 : 0.19 관계 :  특수관계인
# 지분율 : 5.12 관계 :  특수관계인
# 지분율 : 11.95 관계 :  특수관계인
# 지분율 : 0.2 관계 :  특수관계인
# 지분율 : 3.72 관계 :  특수관계인
# 지분율 : 1.17 관계 :  특수관계인
# 지분율 : 0.04 관계 :  특수관계인
# 지분율 : 28.2 관계 :  None
# 지분율 : 22.17 관계 :  None
#
# 메리츠증권
# 지분율 : 47.06 관계 :  최대주주 본인
# 지분율 : 0.92 관계 :  최대주주의 최대주주
# 지분율 : 0.05 관계 :  기타
# 지분율 : 0.02 관계 :  최대주주의 임원
# 지분율 : 0.0 관계 :  최대주주의 임원
# 지분율 : 48.05 관계 :  None
# 지분율 : 0 관계 :  None
#
# NH투자증권
# 지분율 : 49.11 관계 :  최대주주
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 49.12 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# 한국가스공사
# 지분율 : 26.15 관계 :  본인
# 지분율 : 20.47 관계 :  특수관계인
# 지분율 : 6.0 관계 :  특수관계인
# 지분율 : 52.62 관계 :  None
# 지분율 : 0 관계 :  None
#
# 한화시스템
# 지분율 : 48.99 관계 :  최대주주
# 지분율 : 13.41 관계 :  계열회사
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 62.44 관계 :  None
# 지분율 : 0 관계 :  None
#
# 두산퓨얼셀
# 지분율 : 19.49 관계 :  최대주주
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.1 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.33 관계 :  특수관계인
# 지분율 : 1.12 관계 :  특수관계인
# 지분율 : 1.95 관계 :  특수관계인
# 지분율 : 0.91 관계 :  특수관계인
# 지분율 : 0.11 관계 :  특수관계인
# 지분율 : 0.83 관계 :  특수관계인
# 지분율 : 15.29 관계 :  계열회사
# 지분율 : 0.1 관계 :  특수관계인
# 지분율 : 0.6 관계 :  특수관계인
# 지분율 : 0.07 관계 :  특수관계인
# 지분율 : 0.6 관계 :  특수관계인
# 지분율 : 0.07 관계 :  특수관계인
# 지분율 : 0.64 관계 :  특수관계인
# 지분율 : 1.17 관계 :  특수관계인
# 지분율 : 0.53 관계 :  특수관계인
# 지분율 : 0.96 관계 :  특수관계인
# 지분율 : 0.08 관계 :  특수관계인
# 지분율 : 12.47 관계 :  계열회사
# 지분율 : 0.1 관계 :  특수관계인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 1.45 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.04 관계 :  특수관계인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.18 관계 :  특수관계인
# 지분율 : 2.48 관계 :  특수관계인
# 지분율 : 0.41 관계 :  특수관계인
# 지분율 : 1.65 관계 :  특수관계인
# 지분율 : 1.49 관계 :  특수관계인
# 지분율 : 1.32 관계 :  특수관계인
# 지분율 : 0.99 관계 :  특수관계인
# 지분율 : 2.61 관계 :  특수관계인
# 지분율 : 7.4 관계 :  특수관계인
# 지분율 : 0.43 관계 :  특수관계인
# 지분율 : 0.97 관계 :  특수관계인
# 지분율 : 0.21 관계 :  특수관계인
# 지분율 : 0.48 관계 :  특수관계인
# 지분율 : 1.07 관계 :  특수관계인
# 지분율 : 46.59 관계 :  None
# 지분율 : 34.46 관계 :  None
#
# 일진머티리얼즈
# 지분율 : 53.3 관계 :  대표이사
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 53.37 관계 :  None
# 지분율 : 0 관계 :  None
#
# 호텔신라
# 지분율 : 7.3 관계 :  최대주주 본인
# 지분율 : 0.2 관계 :  최대주주 본인
# 지분율 : 5.1 관계 :  특수관계인
# 지분율 : 3.1 관계 :  특수관계인
# 지분율 : 1.3 관계 :  특수관계인
# 지분율 : 0.1 관계 :  특수관계인
# 지분율 : 17.1 관계 :  None
# 지분율 : 0 관계 :  None
#
# 한솔케미칼
# 지분율 : 14.47 관계 :  본인
# 지분율 : 0.31 관계 :  친인척
# 지분율 : 0.13 관계 :  친인척
# 지분율 : 0.03 관계 :  친인척
# 지분율 : 0.04 관계 :  발행회사 임원
# 지분율 : 14.99 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# GS리테일
# 지분율 : 65.75 관계 :  최대주주
# 지분율 : 0.03 관계 :  특수관계자
# 지분율 : 65.78 관계 :  None
# 지분율 : 0 관계 :  None
#
# 씨에스윈드
# 지분율 : 35.51 관계 :  최대주주
# 지분율 : 0.01 관계 :  친인척
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 0.01 관계 :  친인척
# 지분율 : 0.01 관계 :  친인척
# 지분율 : 0.06 관계 :  친인척
# 지분율 : 0.06 관계 :  친인척
# 지분율 : 0.06 관계 :  친인척
# 지분율 : 0.01 관계 :  임원
# 지분율 : 0.02 관계 :  임원
# 지분율 : 0.02 관계 :  임원
# 지분율 : 5.86 관계 :  자녀
# 지분율 : 0.04 관계 :  임원
# 지분율 : 0.01 관계 :  임원
# 지분율 : 0.0 관계 :  사외이사
# 지분율 : 0.01 관계 :  사외이사
# 지분율 : 5.21 관계 :  자녀
# 지분율 : 4.35 관계 :  배우자
# 지분율 : 1.09 관계 :  친인척
# 지분율 : 0.01 관계 :  친인척
# 지분율 : 0.06 관계 :  형제자매
# 지분율 : 0.07 관계 :  형제자매
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 52.44 관계 :  None
# 지분율 : 0 관계 :  None
#
# OCI
# 지분율 : 5.43 관계 :  최대주주 본인
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 0.23 관계 :  친인척
# 지분율 : 0.21 관계 :  친인척
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 0.05 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 5.4 관계 :  친인척
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.63 관계 :  친인척
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 0.0 관계 :  기타
# 지분율 : 1.23 관계 :  재단
# 지분율 : 0.36 관계 :  기타
# 지분율 : 0.42 관계 :  계열사
# 지분율 : 0.83 관계 :  친인척
# 지분율 : 5.04 관계 :  친인척
# 지분율 : 1.89 관계 :  친인척
# 지분율 : 0.49 관계 :  친인척
# 지분율 : 0.18 관계 :  친인척
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 22.44 관계 :  None
# 지분율 : 22.44 관계 :  None
#
# SK케미칼
# 지분율 : 33.47 관계 :  최대주주
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 1.06 관계 :  특수관계인
# 지분율 : 0.02 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.01 관계 :  계열사 임원
# 지분율 : 0.43 관계 :  특수관계인
# 지분율 : 3.11 관계 :  특수관계인
# 지분율 : 0.07 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.21 관계 :  특수관계인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.35 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 35.21 관계 :  None
# 지분율 : 3.56 관계 :  None
#
# 키움증권
# 지분율 : 44.94 관계 :  최대주주
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 44.97 관계 :  None
# 지분율 : 0 관계 :  None
#
# 대우건설
# 지분율 : 50.75 관계 :  최대주주
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 50.76 관계 :  None
# 지분율 : 0 관계 :  None
#
# 한국항공우주
# 지분율 : 26.41 관계 :  최대주주
# 지분율 : 26.41 관계 :  None
# 지분율 : 0 관계 :  None
#
# 롯데쇼핑
# 지분율 : 40.0 관계 :  최대주주
# 지분율 : 0.78 관계 :  계열회사
# 지분율 : 0.15 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.0 관계 :  최대주주의 임원
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 10.23 관계 :  최대주주의 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.71 관계 :  특수관계인
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 1.05 관계 :  특수관계인
# 지분율 : 0.09 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 8.86 관계 :  계열회사
# 지분율 : 61.89 관계 :  None
# 지분율 : 0 관계 :  None
#
# 효성티앤씨
# 지분율 : 20.32 관계 :  최대주주 본인
# 지분율 : 14.59 관계 :  계열회사 임원
# 지분율 : 8.19 관계 :  기타
# 지분율 : 0.73 관계 :  기타
# 지분율 : 0.01 관계 :  기타
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.03 관계 :  기타
# 지분율 : 0.03 관계 :  기타
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 43.93 관계 :  None
# 지분율 : 0 관계 :  None
#
# CJ
# 지분율 : 42.07 관계 :  최대주주 본인
# 지분율 : 0.43 관계 :  재단
# 지분율 : 0.45 관계 :  재단
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.02 관계 :  계열회사 임원
# 지분율 : 0.02 관계 :  계열회사 임원
# 지분율 : 0.03 관계 :  최대주주 외숙부의 처
# 지분율 : 0.04 관계 :  최대주주 외숙부의 처
# 지분율 : 1.19 관계 :  최대주주의 자녀
# 지분율 : 22.72 관계 :  최대주주의 자녀
# 지분율 : 2.75 관계 :  최대주주의 자녀
# 지분율 : 22.98 관계 :  최대주주의 자녀
# 지분율 : 0.56 관계 :  재단
# 지분율 : 0.58 관계 :  재단
# 지분율 : 47.07 관계 :  None
# 지분율 : 46.79 관계 :  None
# 에스원
# 지분율 : 25.65 관계 :  본인
# 지분율 : 25.65 관계 :  None
# 지분율 : 0 관계 :  None
#
# BGF리테일
# 지분율 : 30.0 관계 :  본인
# 지분율 : 0.08 관계 :  특수관계인
# 지분율 : 0.06 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.02 관계 :  계열회사임원
# 지분율 : 0.03 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.01 관계 :  계열회사임원
# 지분율 : 7.36 관계 :  특수관계인
# 지분율 : 0.01 관계 :  계열회사임원
# 지분율 : 0.01 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.01 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.01 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.03 관계 :  계열회사임원
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 3.17 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 5.33 관계 :  특수관계인
# 지분율 : 4.97 관계 :  특수관계인
# 지분율 : 1.46 관계 :  특수관계인
# 지분율 : 1.56 관계 :  특수관계인
# 지분율 : 1.04 관계 :  특수관계인
# 지분율 : 0.11 관계 :  특수관계인
# 지분율 : 55.29 관계 :  None
# 지분율 : 0 관계 :  None
#
# 대우조선해양
# 지분율 : 55.7 관계 :  최대주주
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 55.7 관계 :  None
# 지분율 : 0 관계 :  None
#
# 포스코인터내셔널
# 지분율 : 62.9 관계 :  최대주주
# 지분율 : 0.1 관계 :  기타
# 지분율 : 0.3 관계 :  기타
# 지분율 : 0.0 관계 :  계열사
# 지분율 : 0.0 관계 :  등기임원
# 지분율 : 0.0 관계 :  등기임원
# 지분율 : 0.0 관계 :  등기임원
# 지분율 : 63.3 관계 :  None
# 지분율 : 0 관계 :  None
#
# 현대로템
# 지분율 : 33.77 관계 :  최대주주
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 33.77 관계 :  None
# 지분율 : 0 관계 :  None
#
# 동서
# 지분율 : 17.39 관계 :  최대주주
# 지분율 : 2.13 관계 :  특수관계인
# 지분율 : 0.3 관계 :  특수관계인
# 지분율 : 0.07 관계 :  특수관계인
# 지분율 : 0.07 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 18.98 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 0.09 관계 :  특수관계인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.04 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 12.59 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.05 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 3.61 관계 :  특수관계인
# 지분율 : 2.01 관계 :  특수관계인
# 지분율 : 3.76 관계 :  특수관계인
# 지분율 : 3.61 관계 :  특수관계인
# 지분율 : 0.05 관계 :  특수관계인
# 지분율 : 2.37 관계 :  특수관계인
# 지분율 : 67.36 관계 :  None
# 지분율 : 0 관계 :  None
#
# 만도
# 지분율 : 30.25 관계 :  본인
# 지분율 : 0.01 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 30.26 관계 :  None
# 지분율 : 0 관계 :  None
#
# 한샘
# 지분율 : 15.45 관계 :  본인
# 지분율 : 0.01 관계 :  기타
# 지분율 : 0.0 관계 :  기타
# 지분율 : 0.0 관계 :  기타
# 지분율 : 0.01 관계 :  기타
# 지분율 : 0.03 관계 :  기타
# 지분율 : 0.07 관계 :  친인척
# 지분율 : 1.32 관계 :  친인척
# 지분율 : 0.72 관계 :  친인척
# 지분율 : 0.88 관계 :  친인척
# 지분율 : 0.91 관계 :  친인척
# 지분율 : 0.64 관계 :  등기임원
# 지분율 : 0.06 관계 :  친인척
# 지분율 : 0.3 관계 :  친인척
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 0.52 관계 :  계열회사
# 지분율 : 5.52 관계 :  기타
# 지분율 : 0.74 관계 :  계열회사
# 지분율 : 0.25 관계 :  등기임원
# 지분율 : 0.09 관계 :  등기임원
# 지분율 : 0.0 관계 :  등기임원
# 지분율 : 0.21 관계 :  등기임원
# 지분율 : 2.17 관계 :  기타
# 지분율 : 0.28 관계 :  기타
# 지분율 : 0.0 관계 :  기타
# 지분율 : 30.19 관계 :  None
# 지분율 : 0 관계 :  None
#
# 현대미포조선
# 지분율 : 42.4 관계 :  최대주주
# 지분율 : 0.14 관계 :  본인
# 지분율 : 0.43 관계 :  기타
# 지분율 : 0.01 관계 :  대표이사
# 지분율 : 0.01 관계 :  계열회사임원
# 지분율 : 0.01 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 43.0 관계 :  None
# 지분율 : 0 관계 :  None
#
# 한화생명
# 지분율 : 25.09 관계 :  본인(최대주주)
# 지분율 : 18.15 관계 :  계열사
# 지분율 : 1.75 관계 :  계열사
# 지분율 : 0.03 관계 :  임원
# 지분율 : 0.02 관계 :  임원
# 지분율 : 0.01 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 45.05 관계 :  None
# 지분율 : 0 관계 :  None
#
# 제일기획
# 지분율 : 25.24 관계 :  본인
# 지분율 : 3.04 관계 :  특수관계인
# 지분율 : 0.29 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 28.58 관계 :  None
# 지분율 : 0 관계 :  None
#
# 휠라홀딩스
# 지분율 : 21.64 관계 :  최대주주 본인
# 지분율 : 0.02 관계 :  기타
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 21.64 관계 :  None
# 지분율 : 0 관계 :  None
#
# 효성첨단소재
# 지분율 : 21.2 관계 :  최대주주 본인
# 지분율 : 10.18 관계 :  기타
# 지분율 : 12.21 관계 :  계열회사 임원
# 지분율 : 0.73 관계 :  기타
# 지분율 : 0.01 관계 :  기타
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 0.03 관계 :  기타
# 지분율 : 0.03 관계 :  기타
# 지분율 : 44.41 관계 :  None
# 지분율 : 0 관계 :  None
#
# 신세계
# 지분율 : 18.56 관계 :  최대주주 본인
# 지분율 : 10.0 관계 :  최대주주의 모
# 지분율 : 0.01 관계 :  임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 28.57 관계 :  None
# 지분율 : 0 관계 :  None
#
# 한화
# 지분율 : 22.65 관계 :  최대주주 본인
# 지분율 : 0.0 관계 :  최대주주의 자
# 지분율 : 1.67 관계 :  최대주주의 자
# 지분율 : 0.0 관계 :  최대주주의 자
# 지분율 : 1.42 관계 :  최대주주의 배우자
# 지분율 : 0.0 관계 :  최대주주의 배우자
# 지분율 : 0.17 관계 :  최대주주의 혈족6촌
# 지분율 : 0.0 관계 :  최대주주의 혈족6촌
# 지분율 : 0.04 관계 :  발행회사 임원
# 지분율 : 0.09 관계 :  발행회사 임원
# 지분율 : 0.01 관계 :  발행회사 임원
# 지분율 : 6.4 관계 :  최대주주 본인
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.05 관계 :  발행회사 임원
# 지분율 : 4.44 관계 :  최대주주의 자
# 지분율 : 3.75 관계 :  최대주주의 자
# 지분율 : 4.24 관계 :  계열회사
# 지분율 : 4.82 관계 :  계열회사
# 지분율 : 1.83 관계 :  재단
# 지분율 : 0.0 관계 :  재단
# 지분율 : 1.67 관계 :  최대주주의 자
# 지분율 : 38.14 관계 :  None
# 지분율 : 15.12 관계 :  None
#
# DB하이텍
# 지분율 : 12.42 관계 :  최대주주
# 지분율 : 0.78 관계 :  계열회사
# 지분율 : 0.16 관계 :  비영리단체
# 지분율 : 3.61 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.39 관계 :  특수관계인
# 지분율 : 0.0 관계 :  임 원
# 지분율 : 0.0 관계 :  None
# 지분율 : 17.35 관계 :  None
# 지분율 : 0.0 관계 :  None
# data가 없습니다.
#
# BNK금융지주
# 지분율 : 13.5 관계 :  본인
# 지분율 : 13.5 관계 :  None
# 지분율 : 0 관계 :  None
#
# 한화에어로스페이스
# 지분율 : 33.95 관계 :  본인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 33.98 관계 :  None
# 지분율 : 0 관계 :  None
#
# 현대위아
# 지분율 : 25.35 관계 :  최대주주
# 지분율 : 13.44 관계 :  계열사
# 지분율 : 1.95 관계 :  계열회사 임원
# 지분율 : 0.01 관계 :  계열회사 임원
# 지분율 : 40.75 관계 :  None
# 지분율 : 0 관계 :  None
#
# 효성
# 지분율 : 9.43 관계 :  친인척
# 지분율 : 0.06 관계 :  친인척
# 지분율 : 0.06 관계 :  친인척
# 지분율 : 0.06 관계 :  친인척
# 지분율 : 1.39 관계 :  재단
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 21.94 관계 :  본인
# 지분율 : 21.42 관계 :  친인척
# 지분율 : 0.48 관계 :  친인척
# 지분율 : 0.01 관계 :  친인척
# 지분율 : 0.01 관계 :  임원
# 지분율 : 0.09 관계 :  친인척
# 지분율 : 0.09 관계 :  친인척
# 지분율 : 0.06 관계 :  친인척
# 지분율 : 55.11 관계 :  None
# 지분율 : 0 관계 :  None
#
# 코오롱인더
# 지분율 : 34.1 관계 :  최대주주 본인
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 8.29 관계 :  최대주주 본인
# 지분율 : 1.21 관계 :  최대주주의 최대주주
# 지분율 : 0.01 관계 :  친인척
# 지분율 : 0.04 관계 :  친인척
# 지분율 : 0.04 관계 :  친인척
# 지분율 : 0.01 관계 :  발행회사임원/계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 35.42 관계 :  None
# 지분율 : 8.29 관계 :  None
#
# 현대해상
# 지분율 : 21.9 관계 :  최대주주 본인
# 지분율 : 0.4 관계 :  최대주주 본인의 子
# 지분율 : 0.22 관계 :  최대주주 본인의 子
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 22.53 관계 :  None
# 지분율 : 0 관계 :  None
#
# 하이트진로
# 지분율 : 50.86 관계 :  최대주주
# 지분율 : 0.0 관계 :  등기임원
# 지분율 : 0.0 관계 :  등기임원
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 2.59 관계 :  계열사
# 지분율 : 2.12 관계 :  재단
# 지분율 : 0.35 관계 :  계열사
# 지분율 : 13.48 관계 :  최대주주
# 지분율 : 2.58 관계 :  미등기임원
# 지분율 : 0.02 관계 :  미등기임원
# 지분율 : 0.01 관계 :  친인척
# 지분율 : 0.76 관계 :  친인척
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 53.81 관계 :  None
# 지분율 : 18.97 관계 :  None
#
# 대한전선
# 지분율 : 54.94 관계 :  최대주주
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 54.94 관계 :  None
# 지분율 : 0 관계 :  None
#
# 대웅
# 지분율 : 11.61 관계 :  본인
# 지분율 : 1.77 관계 :  기타
# 지분율 : 1.77 관계 :  기타
# 지분율 : 0.06 관계 :  임원
# 지분율 : 0.04 관계 :  임원
# 지분율 : 0.01 관계 :  임원
# 지분율 : 6.97 관계 :  친인척
# 지분율 : 5.42 관계 :  친인척
# 지분율 : 0.11 관계 :  친인척
# 지분율 : 0.02 관계 :  친인척
# 지분율 : 0.02 관계 :  친인척
# 지분율 : 9.98 관계 :  재단
# 지분율 : 0.26 관계 :  기타
# 지분율 : 0.16 관계 :  기타
# 지분율 : 38.2 관계 :  None
# 지분율 : 0 관계 :  None
#
# 현대엘리베이터
# 지분율 : 10.6 관계 :  최대주주
# 지분율 : 0.0 관계 :  기타
# 지분율 : 1.4 관계 :  재단
# 지분율 : 0.0 관계 :  계열회사
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 7.8 관계 :  계열회사 임원
# 지분율 : 0.3 관계 :  계열회사 임원
# 지분율 : 5.5 관계 :  기타
# 지분율 : 0.3 관계 :  계열회사 임원
# 지분율 : 0.1 관계 :  계열회사 임원
# 지분율 : 0.1 관계 :  기타
# 지분율 : 0.4 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  기타
# 지분율 : 26.5 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# 엘에스일렉트릭
# 지분율 : 46.0 관계 :  최대주주
# 지분율 : 2.25 관계 :  특수관계인
# 지분율 : 0.0 관계 :  등기임원
# 지분율 : 48.25 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# LS
# 지분율 : 1.87 관계 :  최대주주
# 지분율 : 0.82 관계 :  최대주주의  친인척
# 지분율 : 0.05 관계 :  최대주주의  친인척
# 지분율 : 0.05 관계 :  최대주주의  친인척
# 지분율 : 1.46 관계 :  최대주주의  친인척
# 지분율 : 0.54 관계 :  최대주주의  친인척
# 지분율 : 1.16 관계 :  최대주주의  친인척
# 지분율 : 1.55 관계 :  최대주주의  친인척
# 지분율 : 0.82 관계 :  최대주주의  친인척
# 지분율 : 1.94 관계 :  최대주주의  친인척
# 지분율 : 0.45 관계 :  최대주주의  친인척
# 지분율 : 0.65 관계 :  최대주주의  친인척
# 지분율 : 0.39 관계 :  최대주주의  친인척
# 지분율 : 0.69 관계 :  최대주주의  친인척
# 지분율 : 2.99 관계 :  최대주주의  친인척
# 지분율 : 0.69 관계 :  최대주주의  친인척
# 지분율 : 2.4 관계 :  최대주주의  친인척
# 지분율 : 0.58 관계 :  최대주주의  친인척
# 지분율 : 0.58 관계 :  최대주주의  친인척
# 지분율 : 1.85 관계 :  최대주주의  친인척
# 지분율 : 0.81 관계 :  최대주주의  친인척
# 지분율 : 0.81 관계 :  최대주주의  친인척
# 지분율 : 0.02 관계 :  최대주주의  친인척
# 지분율 : 1.63 관계 :  최대주주의  친인척
# 지분율 : 0.77 관계 :  최대주주의  친인척
# 지분율 : 3.63 관계 :  최대주주의  친인척
# 지분율 : 0.49 관계 :  최대주주의  친인척
# 지분율 : 0.2 관계 :  최대주주의  친인척
# 지분율 : 0.2 관계 :  최대주주의  친인척
# 지분율 : 0.2 관계 :  최대주주의  친인척
# 지분율 : 0.04 관계 :  최대주주의  친인척
# 지분율 : 0.49 관계 :  최대주주의  친인척
# 지분율 : 0.04 관계 :  최대주주의 친인척
# 지분율 : 0.29 관계 :  최대주주의  친인척
# 지분율 : 0.01 관계 :  최대주주의 친인척
# 지분율 : 0.03 관계 :  최대주주의 친인척
# 지분율 : 0.03 관계 :  최대주주의 친인척
# 지분율 : 0.03 관계 :  최대주주의 친인척
# 지분율 : 0.06 관계 :  최대주주의 친인척
# 지분율 : 0.06 관계 :  최대주주의 친인척
# 지분율 : 0.06 관계 :  최대주주의 친인척
# 지분율 : 0.06 관계 :  최대주주의 친인척
# 지분율 : 0.3 관계 :  공익재단
# 지분율 : 0.29 관계 :  최대주주의  친인척
# 지분율 : 0.08 관계 :  최대주주의  친인척
# 지분율 : 2.23 관계 :  최대주주의  친인척
# 지분율 : 0.25 관계 :  최대주주의  친인척
# 지분율 : 0.6 관계 :  최대주주의  친인척
# 지분율 : 35.21 관계 :  None
# 지분율 : 0 관계 :  None
#
# 한전기술
# 지분율 : 65.77 관계 :  최대주주 본인
# 지분율 : 65.77 관계 :  None
# 지분율 : 0 관계 :  None
# 대웅제약
# 지분율 : 45.07 관계 :  최대주주
# 지분율 : 0.52 관계 :  -
# 지분율 : 0.3 관계 :  -
# 지분율 : 8.62 관계 :  재단
# 지분율 : 0.04 관계 :  -
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 54.55 관계 :  None
# 지분율 : 0 관계 :  None
#
# 현대백화점
# 지분율 : 2.63 관계 :  최대주주의
# 父
# 지분율 : 17.09 관계 :  최대주주
# (본    인)
# 지분율 : 12.05 관계 :  계열회사
# 지분율 : 4.31 관계 :  계열회사
# 지분율 : 36.08 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# 오뚜기
# 지분율 : 27.31 관계 :  본인
# 지분율 : 0.16 관계 :  제
# 지분율 : 0.19 관계 :  제
# 지분율 : 0.19 관계 :  제
# 지분율 : 0.27 관계 :  조카
# 지분율 : 0.27 관계 :  조카
# 지분율 : 0.27 관계 :  조카
# 지분율 : 0.25 관계 :  조카
# 지분율 : 0.0 관계 :  질서
# 지분율 : 0.03 관계 :  사위
# 지분율 : 0.01 관계 :  이사
# 지분율 : 3.1 관계 :  매
# 지분율 : 0.0 관계 :  사외이사
# 지분율 : 7.83 관계 :  재단
# 지분율 : 0.44 관계 :  계열사
# 지분율 : 0.0 관계 :  계열사
# 지분율 : 3.25 관계 :  계열사
# 지분율 : 1.27 관계 :  계열사
# 지분율 : 0.27 관계 :  계열사
# 지분율 : 3.1 관계 :  매
# 지분율 : 4.5 관계 :  숙부
# 지분율 : 2.17 관계 :  자
# 지분율 : 1.17 관계 :  자
# 지분율 : 0.27 관계 :  처
# 지분율 : 0.69 관계 :  제
# 지분율 : 0.12 관계 :  제
# 지분율 : 51.92 관계 :  None
# 지분율 : 5.23 관계 :  None
# 지분율 : 57.15 관계 :  None
#
# HDC현대산업개발
# 지분율 : 40.0 관계 :  최대주주
# 지분율 : 0.06 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.67 관계 :  특수관계인
# 지분율 : 0.47 관계 :  특수관계인
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  계열회사
# 지분율 : 0.27 관계 :  특수관계인
# 지분율 : 41.48 관계 :  None
# 지분율 : 0 관계 :  None
#
# 동국제강
# 지분율 : 13.94 관계 :  최대주주 본인
# 지분율 : 0.15 관계 :  최대주주 제의 자
# 지분율 : 0.02 관계 :  최대주주의 매제
# 지분율 : 0.0 관계 :  최대주주 매의 자
# 지분율 : 0.01 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  발행회사 임원
# 지분율 : 0.0 관계 :  발행회사 임원(미등기)
# 지분율 : 9.43 관계 :  최대주주의 제
# 지분율 : 0.59 관계 :  최대주주의 매
# 지분율 : 0.37 관계 :  최대주주의 매
# 지분율 : 0.83 관계 :  최대주주의 자
# 지분율 : 0.15 관계 :  최대주주의 모
# 지분율 : 0.26 관계 :  최대주주의 처
# 지분율 : 0.27 관계 :  최대주주의 자
# 지분율 : 0.15 관계 :  최대주주 제의 자
# 지분율 : 26.16 관계 :  None
# 지분율 : 0 관계 :  None
#
# 롯데정밀화학
# 지분율 : 31.13 관계 :  최대주주 본인
# 지분율 : 31.13 관계 :  None
# 지분율 : 0 관계 :  None
#
# 영원무역
# 지분율 : 50.52 관계 :  최대주주
# 본인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.18 관계 :  특수관계인
# 지분율 : 50.74 관계 :  None
# 지분율 : 0 관계 :  None
#
# 농심
# 지분율 : 32.72 관계 :  최대주주
# 지분율 : 5.75 관계 :  특수관계인
# 지분율 : 0.54 관계 :  특수관계인
# 지분율 : 4.83 관계 :  특수관계인
# 지분율 : 1.64 관계 :  특수관계인
# 지분율 : 45.49 관계 :  None
# 지분율 : 0 관계 :  None
#
# 아시아나항공
# 지분율 : 30.77 관계 :  본인
# 지분율 : 0.0 관계 :  기타
# 지분율 : 0.01 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 30.78 관계 :  None
# 지분율 : 0 관계 :  None
#
# 한전KPS
# 지분율 : 51.0 관계 :  모회사
# 지분율 : 51.0 관계 :  None
# 지분율 : 0 관계 :  None
#
# 금호타이어
# 지분율 : 45.0 관계 :  최대주주
# 지분율 : 45.0 관계 :  None
# 지분율 : 0 관계 :  None
#
# 후성
# 지분율 : 22.7 관계 :  본인
# 지분율 : 0.01 관계 :  친인척
# 지분율 : 0.07 관계 :  대표이사
# 지분율 : 15.37 관계 :  그룹회장
# 지분율 : 6.58 관계 :  특수관계자
# 지분율 : 4.23 관계 :  특수관계자
# 지분율 : 0.32 관계 :  특수관계자
# 지분율 : 0.09 관계 :  친인척
# 지분율 : 0.08 관계 :  친인척
# 지분율 : 0.05 관계 :  친인척
# 지분율 : 0.09 관계 :  친인척
# 지분율 : 49.59 관계 :  None
# 지분율 : 0 관계 :  None
#
# 녹십자홀딩스
# 지분율 : 12.16 관계 :  본인
# 지분율 : 0.32 관계 :  특수관계인
# 지분율 : 0.32 관계 :  특수관계인
# 지분율 : 0.52 관계 :  특수관계인
# 지분율 : 0.25 관계 :  특수관계인
# 지분율 : 0.21 관계 :  특수관계인
# 지분율 : 0.25 관계 :  특수관계인
# 지분율 : 0.72 관계 :  특수관계인
# 지분율 : 3.26 관계 :  특수관계인
# 지분율 : 0.22 관계 :  특수관계인
# 지분율 : 1.48 관계 :  특수관계인
# 지분율 : 0.33 관계 :  특수관계인
# 지분율 : 1.71 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 4.87 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 1.08 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 8.73 관계 :  특수관계인
# 지분율 : 0.69 관계 :  특수관계인
# 지분율 : 4.38 관계 :  특수관계인
# 지분율 : 2.1 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.27 관계 :  특수관계인
# 지분율 : 0.64 관계 :  특수관계인
# 지분율 : 0.62 관계 :  특수관계인
# 지분율 : 2.6 관계 :  특수관계인
# 지분율 : 2.91 관계 :  특수관계인
# 지분율 : 0.04 관계 :  특수관계인
# 지분율 : 50.7 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# 대한유화
# 지분율 : 2.55 관계 :  본인
# 지분율 : 0.06 관계 :  친인척
# 지분율 : 0.06 관계 :  친인척
# 지분율 : 0.01 관계 :  임원
# 지분율 : 31.01 관계 :  계열사
# 지분율 : 0.92 관계 :  친인척
# 지분율 : 1.81 관계 :  친인척
# 지분율 : 1.6 관계 :  친인척
# 지분율 : 0.56 관계 :  친인척
# 지분율 : 0.7 관계 :  친인척
# 지분율 : 0.23 관계 :  친인척
# 지분율 : 0.29 관계 :  친인척
# 지분율 : 0.07 관계 :  친인척
# 지분율 : 39.87 관계 :  None
# 지분율 : 0 관계 :  None
#
# DL
# 지분율 : 21.67 관계 :  최대주주
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 1.26 관계 :  특수관계인
# 지분율 : 0.04 관계 :  특수관계인
# 지분율 : 0.08 관계 :  특수관계인
# 지분율 : 0.06 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 5.4 관계 :  특수관계인
# 지분율 : 0.66 관계 :  최대주주
# 지분율 : 23.12 관계 :  None
# 지분율 : 6.15 관계 :  None
#
# 한국앤컴퍼니
# 지분율 : 0.0 관계 :  최대주주의 친인척
# 지분율 : 0.0 관계 :  최대주주의 친인척
# 지분율 : 0.0 관계 :  최대주주의 친인척
# 지분율 : 0.0 관계 :  최대주주의 친인척
# 지분율 : 0.03 관계 :  기타
# 지분율 : 19.32 관계 :  최대주주의 친인척
# 지분율 : 42.9 관계 :  최대주주 본인
# 지분율 : 10.82 관계 :  최대주주의 친인척
# 지분율 : 0.83 관계 :  최대주주의 친인척
# 지분율 : 0.01 관계 :  최대주주의 친인척
# 지분율 : 0.01 관계 :  최대주주의 친인척
# 지분율 : 0.0 관계 :  최대주주의 친인척
# 지분율 : 0.0 관계 :  최대주주의 친인척
# 지분율 : 73.92 관계 :  None
# 지분율 : 0 관계 :  None
#
# 코스맥스
# 지분율 : 26.24 관계 :  최대주주
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.25 관계 :  임원
# 지분율 : 0.04 관계 :  임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.01 관계 :  계열회사임원
# 지분율 : 0.01 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 26.55 관계 :  None
# 지분율 : 0 관계 :  None
# 지분율 : 0 관계 :  None
#
# 종근당
# 지분율 : 24.4 관계 :  본인
# 지분율 : 9.5 관계 :  임원
# 지분율 : 1.5 관계 :  친인척
# 지분율 : 1.2 관계 :  친인척
# 지분율 : 1.2 관계 :  친인척
# 지분율 : 0.1 관계 :  친인척
# 지분율 : 37.7 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# F&F 홀딩스
# 지분율 : 45.01 관계 :  본인
# 지분율 : 3.57 관계 :  친인척
# 지분율 : 2.79 관계 :  친인척
# 지분율 : 2.6 관계 :  친인척
# 지분율 : 2.08 관계 :  친인척
# 지분율 : 1.09 관계 :  친인척
# 지분율 : 1.09 관계 :  친인척
# 지분율 : 0.37 관계 :  친인척
# 지분율 : 0.22 관계 :  친인척
# 지분율 : 58.82 관계 :  None
# 지분율 : 0 관계 :  None
#
# KG동부제철
# 지분율 : 39.97 관계 :  최대주주
# 지분율 : 0.01 관계 :  발행회사
# 지분율 : 0.0 관계 :  발행회사
# 지분율 : 39.98 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# 두산
# 지분율 : 7.41 관계 :  본인
# 지분율 : 4.26 관계 :  친인척
# 지분율 : 0.33 관계 :  친인척
# 지분율 : 3.64 관계 :  친인척
# 지분율 : 1.95 관계 :  친인척
# 지분율 : 2.98 관계 :  친인척
# 지분율 : 0.11 관계 :  친인척
# 지분율 : 2.7 관계 :  친인척
# 지분율 : 0.1 관계 :  친인척
# 지분율 : 1.99 관계 :  친인척
# 지분율 : 0.07 관계 :  친인척
# 지분율 : 0.41 관계 :  본인
# 지분율 : 1.99 관계 :  친인척
# 지분율 : 0.07 관계 :  친인척
# 지분율 : 1.96 관계 :  친인척
# 지분율 : 1.17 관계 :  친인척
# 지분율 : 1.63 관계 :  친인척
# 지분율 : 0.96 관계 :  친인척
# 지분율 : 0.1 관계 :  친인척
# 지분율 : 0.12 관계 :  친인척
# 지분율 : 0.04 관계 :  친인척
# 지분율 : 0.03 관계 :  친인척
# 지분율 : 4.94 관계 :  친인척
# 지분율 : 0.04 관계 :  친인척
# 지분율 : 0.03 관계 :  친인척
# 지분율 : 0.04 관계 :  친인척
# 지분율 : 0.04 관계 :  친인척
# 지분율 : 0.01 관계 :  친인척
# 지분율 : 0.01 관계 :  친인척
# 지분율 : 0.01 관계 :  친인척
# 지분율 : 0.01 관계 :  친인척
# 지분율 : 0.01 관계 :  친인척
# 지분율 : 0.01 관계 :  친인척
# 지분율 : 0.21 관계 :  친인척
# 지분율 : 0.01 관계 :  친인척
# 지분율 : 0.01 관계 :  친인척
# 지분율 : 0.05 관계 :  친인척
# 지분율 : 0.04 관계 :  친인척
# 지분율 : 0.04 관계 :  친인척
# 지분율 : 0.22 관계 :  친인척
# 지분율 : 2.48 관계 :  친인척
# 지분율 : 1.65 관계 :  친인척
# 지분율 : 1.49 관계 :  친인척
# 지분율 : 1.32 관계 :  친인척
# 지분율 : 2.46 관계 :  친인척
# 지분율 : 0.99 관계 :  친인척
# 지분율 : 3.09 관계 :  비영리법인
# 지분율 : 21.28 관계 :  비영리법인
# 지분율 : 0.52 관계 :  비영리법인
# 지분율 : 0.01 관계 :  등기임원
# 지분율 : 0.0 관계 :  등기임원
# 지분율 : 1.07 관계 :  친인척
# 지분율 : 3.48 관계 :  친인척
# 지분율 : 3.44 관계 :  친인척
# 지분율 : 0.1 관계 :  친인척
# 지분율 : 47.24 관계 :  None
# 지분율 : 35.87 관계 :  None
#
# 동원시스템즈
# 지분율 : 80.39 관계 :  최대주주
# 지분율 : 30.77 관계 :  최대주주
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 0.08 관계 :  특수관계인
# 지분율 : 0.31 관계 :  특수관계인
# 지분율 : 2.05 관계 :  특수관계인
# 지분율 : 0.04 관계 :  특수관계인
# 지분율 : 4.08 관계 :  특수관계인
# 지분율 : 80.84 관계 :  None
# 지분율 : 36.9 관계 :  None
#
# 아이에스동서
# 지분율 : 44.49 관계 :  최대주주
# 지분율 : 0.97 관계 :  특수관계인
# 지분율 : 7.93 관계 :  특수관계인
# 지분율 : 1.09 관계 :  특수관계인
# 지분율 : 0.2 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 54.69 관계 :  None
# 지분율 : 0 관계 :  None
#
# 부광약품
# 지분율 : 9.93 관계 :  본인
# 지분율 : 0.09 관계 :  직계비속
# 지분율 : 0.07 관계 :  임원
# 지분율 : 0.03 관계 :  임원
# 지분율 : 7.71 관계 :  직계비속
# 지분율 : 2.79 관계 :  직계비속
# 지분율 : 2.97 관계 :  직계비속
# 지분율 : 0.48 관계 :  직계비속
# 지분율 : 0.1 관계 :  직계비속
# 지분율 : 0.09 관계 :  직계비속
# 지분율 : 0.09 관계 :  직계비속
# 지분율 : 0.09 관계 :  직계비속
# 지분율 : 24.43 관계 :  None
# 지분율 : 0 관계 :  None
#
# 신세계인터내셔날
# 지분율 : 45.76 관계 :  최대주주
# 지분율 : 15.14 관계 :  특수관계인
# 지분율 : 0.02 관계 :  계열회사임원
# 지분율 : 0.01 관계 :  계열회사임원
# 지분율 : 60.93 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# SK네트웍스
# 지분율 : 39.14 관계 :  최대주주
# 본인
# 지분율 : 0.33 관계 :  비영리재단
# 지분율 : 0.83 관계 :  발행회사
# 임원
# 지분율 : 0.08 관계 :  계열사 임원
# 지분율 : 0.02 관계 :  발행회사
# 임원
# 지분율 : 0.02 관계 :  기타
# 지분율 : 0.0 관계 :  계열사 임원
# 지분율 : 40.43 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# 영풍
# 지분율 : 16.89 관계 :  최대주주
# 지분율 : 2.18 관계 :  "
# 지분율 : 0.21 관계 :  "
# 지분율 : 0.76 관계 :  "
# 지분율 : 15.53 관계 :  계열회사
# 지분율 : 4.39 관계 :  "
# 지분율 : 9.18 관계 :  "
# 지분율 : 2.31 관계 :  친인척
# 지분율 : 11.15 관계 :  친인척
# 지분율 : 0.52 관계 :  친인척
# 지분율 : 0.05 관계 :  친인척
# 지분율 : 0.27 관계 :  특수관계인
# 지분율 : 4.14 관계 :  "
# 지분율 : 3.62 관계 :  "
# 지분율 : 2.85 관계 :  "
# 지분율 : 74.05 관계 :  None
# 지분율 : 0 관계 :  None
#
# 지누스
# 지분율 : 35.21 관계 :  최대주주 본인
# 지분율 : 0.04 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.03 관계 :  임원
# 지분율 : 0.05 관계 :  임원
# 지분율 : 0.07 관계 :  임원
# 지분율 : 0.01 관계 :  임원
# 지분율 : 2.89 관계 :  자녀
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 0.0 관계 :  -
# 지분율 : 0.21 관계 :  임원
# 지분율 : 0.02 관계 :  임원
# 지분율 : 0.42 관계 :  임원
# 지분율 : 0.21 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 39.17 관계 :  None
# 지분율 : 0 관계 :  None
#
# 롯데관광개발
# 지분율 : 28.54 관계 :  본인
# 지분율 : 2.03 관계 :  처
# 지분율 : 3.06 관계 :  자
# 지분율 : 2.3 관계 :  자
# 지분율 : 16.2 관계 :  계열사
# 지분율 : 52.13 관계 :  None
# 지분율 : 0.0 관계 :  None
# 한올바이오파마
# 지분율 : 30.8 관계 :  본인
# 지분율 : 0.1 관계 :  임원
# 지분율 : 31.0 관계 :  None
# 지분율 : 0 관계 :  None
#
# 롯데칠성음료
# 지분율 : 39.26 관계 :  최대주주
# 지분율 : 3.54 관계 :  특수
# 관계인
# 지분율 : 7.9 관계 :  특수
# 관계인
# 지분율 : 3.93 관계 :  특수
# 관계인
# 지분율 : 5.59 관계 :  특수
# 관계인
# 지분율 : 5.11 관계 :  특수
# 관계인
# 지분율 : 5.28 관계 :  특수
# 관계인
# 지분율 : 4.83 관계 :  특수
# 관계인
# 지분율 : 1.19 관계 :  특수
# 관계인
# 지분율 : 1.22 관계 :  특수
# 관계인
# 지분율 : 0.01 관계 :  특수
# 관계인
# 지분율 : 8.37 관계 :  최대주주
# 지분율 : 0.01 관계 :  특수
# 관계인
# 지분율 : 0.0 관계 :  특수
# 관계인
# 지분율 : 0.0 관계 :  특수
# 관계인
# 지분율 : 0.0 관계 :  특수
# 관계인
# 지분율 : 0.0 관계 :  특수
# 관계인
# 지분율 : 0.0 관계 :  특수
# 관계인
# 지분율 : 0.0 관계 :  특수
# 관계인
# 지분율 : 0.0 관계 :  특수
# 관계인
# 지분율 : 0.0 관계 :  특수
# 관계인
# 지분율 : 0.0 관계 :  특수
# 관계인
# 지분율 : 0.48 관계 :  특수
# 관계인
# 지분율 : 8.24 관계 :  특수
# 관계인
# 지분율 : 2.75 관계 :  특수
# 관계인
# 지분율 : 6.22 관계 :  특수
# 관계인
# 지분율 : 0.29 관계 :  특수
# 관계인
# 지분율 : 62.8 관계 :  None
# 지분율 : 41.4 관계 :  None
#
# 휴켐스
# 지분율 : 39.95 관계 :  최대주주
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 2.63 관계 :  특수관계인
# 지분율 : 0.83 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  당사 고문
# 지분율 : 0.0 관계 :  당사 임원
# 지분율 : 43.42 관계 :  None
# 지분율 : 0 관계 :  None
#
# 더블유게임즈
# 지분율 : 40.27 관계 :  최대주주
# 지분율 : 1.63 관계 :  등기이사
# 지분율 : 0.36 관계 :  계열회사 임원
# 지분율 : 0.37 관계 :  계열회사 임원
# 지분율 : 0.56 관계 :  미등기이사
# 지분율 : 0.54 관계 :  미등기이사
# 지분율 : 43.73 관계 :  None
# 지분율 : 0 관계 :  None
#
# CJ CGV
# 지분율 : 38.4 관계 :  지배회사
# 지분율 : 0.01 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 38.41 관계 :  None
# 지분율 : 0 관계 :  None
#
# 보령제약
# 지분율 : 38.94 관계 :  본인
# 지분율 : 0.62 관계 :  계열회사 임원
# 지분율 : 11.37 관계 :  임원
# 지분율 : 1.3 관계 :  계열회사 임원
# 지분율 : 4.84 관계 :  계열사
# 지분율 : 0.13 관계 :  재단
# 지분율 : 57.2 관계 :  None
# 지분율 : 0 관계 :  None
#
# 태광산업
# 지분율 : 29.48 관계 :  본인
# 지분율 : 7.49 관계 :  친인척
# 지분율 : 0.8 관계 :  친인척
# 지분율 : 0.8 관계 :  친인척
# 지분율 : 5.0 관계 :  비영리법인
# 지분율 : 11.22 관계 :  계열사
# 지분율 : 0.22 관계 :  친인척
# 지분율 : 55.01 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# LX인터내셔널
# 지분율 : 24.69 관계 :  본인
# 지분율 : 0.15 관계 :  특수관계인
# 지분율 : 1.4 관계 :  특수관계인
# 지분율 : 0.04 관계 :  특수관계인
# 지분율 : 0.02 관계 :  등기임원
# 지분율 : 26.3 관계 :  None
# 지분율 : 0 관계 :  None
#
# 세방전지
# 지분율 : 37.95 관계 :  본인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.88 관계 :  특수관계인
# 지분율 : 0.83 관계 :  특수관계인
# 지분율 : 0.93 관계 :  특수관계인
# 지분율 : 0.88 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 41.54 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# LIG넥스원
# 지분율 : 46.36 관계 :  본인
# 지분율 : 0.03 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.27 관계 :  특수관계인
# 지분율 : 0.18 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.14 관계 :  특수관계인
# 지분율 : 0.02 관계 :  특수관계인
# 지분율 : 47.05 관계 :  None
# 지분율 : 0 관계 :  None
#
# 한국콜마
# 지분율 : 27.14 관계 :  최대주주
# 지분율 : 0.01 관계 :  임원
# 지분율 : 0.01 관계 :  임원
# 지분율 : 0.01 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.01 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  계열회사
# 지분율 : 0.48 관계 :  특수관계인
# 지분율 : 2.41 관계 :  특수관계인
# 지분율 : 0.13 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.01 관계 :  임원
# 지분율 : 0.01 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 30.23 관계 :  None
# 지분율 : 0 관계 :  None
#
# 이노션
# 지분율 : 17.69 관계 :  본인
# 지분율 : 2.0 관계 :  친인척
# 지분율 : 9.0 관계 :  재단
# 지분율 : 28.69 관계 :  None
# 지분율 : 0 관계 :  None
#
# 현대홈쇼핑
# 지분율 : 25.01 관계 :  본인
# 지분율 : 15.8 관계 :  관계사
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 40.82 관계 :  None
# 지분율 : 0 관계 :  None
#
# 두산인프라코어
# 지분율 : 34.97 관계 :  본인
# 지분율 : 0.01 관계 :  계열사임원
# 지분율 : 0.01 관계 :  계열사임원
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 35.0 관계 :  None
# 지분율 : 0 관계 :  None
#
# 쿠쿠홈시스
# 지분율 : 40.55 관계 :  최대주주
# 지분율 : 16.55 관계 :  특수관계인
# 지분율 : 9.32 관계 :  특수관계인
# 지분율 : 7.18 관계 :  특수관계인
# 지분율 : 1.84 관계 :  관계회사
# 지분율 : 75.44 관계 :  None
# 지분율 : 0 관계 :  None
#
# 한섬
# 지분율 : 34.64 관계 :  본 인
# 지분율 : 34.64 관계 :  None
# 지분율 : 0 관계 :  None
#
# 오리온홀딩스
# 지분율 : 32.63 관계 :  본인
# 지분율 : 28.73 관계 :  배우자
# 지분율 : 1.22 관계 :  자녀
# 지분율 : 1.22 관계 :  자녀
# 지분율 : 0.04 관계 :  임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 63.84 관계 :  None
# 지분율 : 63.84 관계 :  None
#
# 화승엔터프라이즈
# 지분율 : 71.73 관계 :  최대주주
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.28 관계 :  기타비상무이사
# 지분율 : 72.02 관계 :  None
# 지분율 : 0 관계 :  None
#
# SK디스커버리
# 지분율 : 40.18 관계 :  본인
# 지분율 : 0.03 관계 :  친인척
# 지분율 : 0.35 관계 :  친인척
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 0.61 관계 :  계열사
# 지분율 : 0.03 관계 :  임원
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.43 관계 :  본인
# 지분율 : 0.11 관계 :  친인척
# 지분율 : 3.11 관계 :  친인척
# 지분율 : 3.42 관계 :  친인척
# 지분율 : 0.02 관계 :  친인척
# 지분율 : 0.11 관계 :  친인척
# 지분율 : 0.0 관계 :  친인척
# 지분율 : 0.27 관계 :  친인척
# 지분율 : 45.11 관계 :  None
# 지분율 : 3.56 관계 :  None
#
# 현대그린푸드
# 지분율 : 23.8 관계 :  최대주주(본인)
# 지분율 : 12.7 관계 :  최대주주의 兄
# 지분율 : 1.9 관계 :  최대주주의 父
# 지분율 : 38.4 관계 :  None
# 지분율 : 0 관계 :  None
#
# 동원산업
# 지분율 : 62.72 관계 :  최대주주
# 지분율 : 0.35 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.11 관계 :  특수관계인
# 지분율 : 0.05 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.06 관계 :  특수관계인
# 지분율 : 63.3 관계 :  None
# 지분율 : 0 관계 :  None
#
# 영진약품
# 지분율 : 52.45 관계 :  최대주주
# 지분율 : 0.0 관계 :  임원
# 지분율 : 52.45 관계 :  None
# 지분율 : 0 관계 :  None
#
# 삼양홀딩스
# 지분율 : 5.81 관계 :  최대주주 본인
# 지분율 : 1.16 관계 :  친인척
# 지분율 : 0.15 관계 :  친인척
# 지분율 : 0.06 관계 :  친인척
# 지분율 : 2.25 관계 :  친인척
# 지분율 : 1.03 관계 :  친인척
# 지분율 : 0.29 관계 :  친인척
# 지분율 : 1.28 관계 :  친인척
# 지분율 : 0.66 관계 :  친인척
# 지분율 : 0.66 관계 :  친인척
# 지분율 : 0.29 관계 :  친인척
# 지분율 : 4.82 관계 :  친인척
# 지분율 : 5.28 관계 :  친인척
# 지분율 : 0.23 관계 :  친인척
# 지분율 : 0.94 관계 :  친인척
# 지분율 : 0.52 관계 :  친인척
# 지분율 : 0.52 관계 :  친인척
# 지분율 : 0.72 관계 :  친인척
# 지분율 : 0.72 관계 :  친인척
# 지분율 : 0.72 관계 :  친인척
# 지분율 : 2.96 관계 :  재단
# 지분율 : 0.01 관계 :  임원
# 지분율 : 0.31 관계 :  친인척
# 지분율 : 0.01 관계 :  임원
# 지분율 : 2.23 관계 :  친인척
# 지분율 : 1.49 관계 :  친인척
# 지분율 : 3.8 관계 :  친인척
# 지분율 : 0.31 관계 :  친인척
# 지분율 : 0.75 관계 :  친인척
# 지분율 : 1.73 관계 :  친인척
# 지분율 : 41.73 관계 :  None
# 지분율 : 0 관계 :  None
#
# GKL
# 지분율 : 51.0 관계 :  본인
# 지분율 : 51.0 관계 :  None
# 지분율 : 0 관계 :  None
#
# 한세실업
# 지분율 : 42.45 관계 :  본인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 5.49 관계 :  특수관계인
# 지분율 : 3.58 관계 :  특수관계인
# 지분율 : 2.94 관계 :  특수관계인
# 지분율 : 0.88 관계 :  특수관계인
# 지분율 : 0.76 관계 :  특수관계인
# 지분율 : 0.34 관계 :  특수관계인
# 지분율 : 0.2 관계 :  특수관계인
# 지분율 : 0.01 관계 :  특수관계인
# 지분율 : 56.66 관계 :  None
# 지분율 : 0 관계 :  None
#
# 풍산
# 지분율 : 38.0 관계 :  본인
# 지분율 : 0.0 관계 :  임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 0.0 관계 :  계열사임원
# 지분율 : 38.01 관계 :  None
# 지분율 : 0 관계 :  None
#
# LX하우시스
# 지분율 : 30.07 관계 :  최대주주 본인
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.0 관계 :  계열회사 임원
# 지분율 : 0.02 관계 :  계열회사 임원
# 지분율 : 30.09 관계 :  None
# 지분율 : 0.0 관계 :  None
#
# 넥센타이어
# 지분율 : 44.25 관계 :  최대주주
# 지분율 : 19.45 관계 :  대표이사 회장
# 지분율 : 3.25 관계 :  대표이사
# 부회장
# 지분율 : 66.95 관계 :  None
# 지분율 : 0 관계 :  None
#
# 롯데하이마트
# 지분율 : 61.01 관계 :  최대주주
# 지분율 : 0.0 관계 :  발행회사임원
# 지분율 : 0.13 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0.01 관계 :  계열회사임원
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 0 관계 :  None
# 지분율 : 61.15 관계 :  None
#
# 동원F&B
# 지분율 : 74.38 관계 :  최대주주
# 지분율 : 0.02 관계 :  임원
# 지분율 : 0.0 관계 :  특수관계인
# 지분율 : 74.4 관계 :  None
# 지분율 : 0 관계 :  None
# 지분율 : 0 관계 :  None
# data가 없습니다.
#
# SNT모티브
# 지분율 : 40.03 관계 :  본인
# 지분율 : 40.03 관계 :  None
# 지분율 : 0 관계 :  None
#
# 일양약품
# 지분율 : 21.84 관계 :  본인
# 지분율 : 0.02 관계 :  임원
# 지분율 : 0.0 관계 :  모
# 지분율 : 0.06 관계 :  제
# 지분율 : 0.35 관계 :  제
# 지분율 : 0.0 관계 :  제
# 지분율 : 0.08 관계 :  제
# 지분율 : 3.92 관계 :  자
# 지분율 : 0.02 관계 :  자
# 지분율 : 0.05 관계 :  임원
# 지분율 : 26.34 관계 :  None
# 지분율 : 0 관계 :  None
#
# 쿠쿠홀딩스
# 지분율 : 42.36 관계 :  최대주주 본인
# 지분율 : 18.37 관계 :  최대주주의 형제
# 지분율 : 6.97 관계 :  최대주주의 부
# 지분율 : 1.37 관계 :  관계회사
# 지분율 : 69.07 관계 :  None
# 지분율 : 0 관계 :  None
#
# 대상
# 지분율 : 1.18 관계 :  최대주주 임원
# 지분율 : 3.14 관계 :  최대주주 임원
# 지분율 : 3.82 관계 :  계열회사
# 지분율 : 39.28 관계 :  최대주주
# 지분율 : 6.49 관계 :  최대주주
# 지분율 : 0.46 관계 :  계열회사 임원
# 지분율 : 44.74 관계 :  None
# 지분율 : 9.64 관계 :  None
#
# JW중외제약
# 지분율 : 39.52 관계 :  본인
# 지분율 : 0.01 관계 :  기타
# 지분율 : 4.78 관계 :  본인
# 지분율 : 0.57 관계 :  발행회사 임원
# 지분율 : 0.03 관계 :  계열사 임원
# 지분율 : 0.02 관계 :  발행회사 임원
# 지분율 : 0.06 관계 :  기타
# 지분율 : 0.06 관계 :  기타
# 지분율 : 0.01 관계 :  기타
# 지분율 : 0.01 관계 :  기타
# 지분율 : 40.29 관계 :  None
# 지분율 : 4.78 관계 :  None
#
# 락앤락
# 지분율 : 65.96 관계 :  최대주주
# 지분율 : 0.11 관계 :  특수
# 관계인
# 지분율 : 0.0 관계 :  특수
# 관계인
# 지분율 : 0.0 관계 :  특수
# 관계인
# 지분율 : 0.0 관계 :  특수
# 관계인
# 지분율 : 0.0 관계 :  특수
# 관계인
# 지분율 : 0.94 관계 :  861223
# 지분율 : 67.01 관계 :  None
# 지분율 : 0 관계 :  None
#
# 삼양식품
# 지분율 : 33.26 관계 :  본인
# 지분율 : 0.0 관계 :  기타특수관계인
# 지분율 : 0.0 관계 :  기타특수관계인
# 지분율 : 1.68 관계 :  재단
# 지분율 : 1.66 관계 :  기타특수관계인
# 지분율 : 0.0 관계 :  계열회사임원
# 지분율 : 3.13 관계 :  기타특수관계인
# 지분율 : 4.33 관계 :  기타특수관계인
# 지분율 : 0.93 관계 :  기타특수관계인
# 지분율 : 0.27 관계 :  기타특수관계인
# 지분율 : 0.19 관계 :  기타특수관계인
# 지분율 : 0.59 관계 :  기타특수관계인
# 지분율 : 0.05 관계 :  기타특수관계인
# 지분율 : 46.11 관계 :  None
# 지분율 : 0 관계 :  None

# %%
#전체 최종
import pandas as pd
from pandas import DataFrame
import requests
import pprint

#특수 관계인 정리
relative_list = [
    "최대주주",
    "본인",
    "본인(최대주주)",
    "최대주주본인",
    "본인및특별관계자",
    "본인및특수관계인",
    "최대주주(본인)",
    "최대주주의최대주주",
    "특수",
    "특수관계",
    "특수관계인",
    "기타특수관계인",
    "최대주주의특별관계자",
    "최대주주의특수관계인",
    "최대주주의직계비속",
    "최대주주의친인척",
    "최대주주의혈족6촌",
    "최대주주의배우자",
    "최대주주의모",
    "최대주주의부",
    "최대주주의자",
    "최대주주의형제",
    "최대주주의매제",
    "최대주주의매",
    "최대주주의제",
    "최대주주의처", 
    "최대주주제의자",
    "최대주주매의자",
    "최대주주의兄",
    "최대주주의父",
    "자녀",
    "배우자",
    "형제자매",
    "친족",
    "친인척",
    "임원\n(친인척)"
    "혈족1촌", 
    "혈족2촌", 
    "혈족3촌", 
    "혈족5촌", 
    "6촌이내의혈족",
    "4촌이내의인척",
    "제",
    "매",
    "조카",
    "사위",
    "숙부",
    "자",
    "처",
    "계열회사",
    "계열사",
    "최대주주의특수관계법인",
    "최대주주의계열회사",
    "최대주주의계열비영리법인",
    "최대주주의계 비영리법인",
    "지배회사",
    "모회사",
    "대표이사"
]

#dart open api 인자
auth_key="2e915b536849f9c4f517c681d00833f8d83ac7ee" 
company_code=""


#excel 파일 읽기 (row : 200개)
xlsx = pd.read_excel('./corp_dataset.xlsx')
ratio_list = []

#비율
trmend_posesn_stock_qota_rt = ''
for i in range(200):
    print('')
    company_name = str(xlsx.name[i])
    print(company_name)
    reprt_code = 11011
    company_code = str(xlsx.code[i]).zfill(8)
    url = 'https://opendart.fss.or.kr/api/hyslrSttus.json?crtfc_key={}&corp_code={}&bsns_year=2020&reprt_code={}'.format(auth_key, company_code, reprt_code)
    res = requests.get(url)
    data = res.json()
    
    if data['status'] == '013':
        while reprt_code < 11015:
            reprt_code += 1
            url = 'https://opendart.fss.or.kr/api/hyslrSttus.json?crtfc_key={}&corp_code={}&bsns_year=2020&reprt_code={}'.format(auth_key, company_code, reprt_code)
            res = requests.get(url)
            data = res.json()
            if data['status'] != '013':
                break
                
    largest = 0
    if data.get('list'):
        share_list = data['list']
        for share in share_list:
            type = share['stock_knd'].replace(" ", "")
            type = type.replace("\n", "")
            if type == '보통주' or type == '보통주식' or type == '의결권있는주식' or type == '의결권이있는주식' or type == '의결권있는보통주' or type == '의결권있는주식(보통주)' or type == '보통주(의결권있음)':
                if share['trmend_posesn_stock_qota_rt'] == '-':
                    ratio = 0
                else:
                    ratio = float(share['trmend_posesn_stock_qota_rt'])

                relative = share.get('relate')
                if relative:
                    relative = relative.replace(" ", "")
                    relative = relative.replace("\n", "")

                if relative in relative_list:
                    largest += ratio
    largest = round(largest, 2)
    ratio_list.append(largest)
    print(f'최대주주 및 특수관계인 지분율 : {largest}')
# Out:
# 삼성전자
# 최대주주 및 특수관계인 지분율 : 21.07
#
# SK하이닉스
# 최대주주 및 특수관계인 지분율 : 20.07
#
# NAVER
# 최대주주 및 특수관계인 지분율 : 11.56
#
# 카카오
# 최대주주 및 특수관계인 지분율 : 25.44
#
# 삼성바이오로직스
# 최대주주 및 특수관계인 지분율 : 75.08
#
# LG화학
# 최대주주 및 특수관계인 지분율 : 30.06
#
# 삼성SDI
# 최대주주 및 특수관계인 지분율 : 19.72
#
# 현대차
# 최대주주 및 특수관계인 지분율 : 21.43
#
# 셀트리온
# 최대주주 및 특수관계인 지분율 : 22.14
#
# 기아
# 최대주주 및 특수관계인 지분율 : 33.88
#
# POSCO
# 최대주주 및 특수관계인 지분율 : 11.75
#
# 현대모비스
# 최대주주 및 특수관계인 지분율 : 23.76
#
# 삼성물산
# 최대주주 및 특수관계인 지분율 : 31.71
#
# LG전자
# 최대주주 및 특수관계인 지분율 : 33.67
#
# SK바이오사이언스
# 최대주주 및 특수관계인 지분율 : 98.04
#
# SK이노베이션
# 최대주주 및 특수관계인 지분율 : 33.41
#
# LG생활건강
# 최대주주 및 특수관계인 지분율 : 34.03
#
# SK텔레콤
# 최대주주 및 특수관계인 지분율 : 26.78
#
# KB금융
# 최대주주 및 특수관계인 지분율 : 9.93
#
# 신한지주
# 최대주주 및 특수관계인 지분율 : 9.81
#
# SK
# 최대주주 및 특수관계인 지분율 : 29.5
#
# HMM
# 최대주주 및 특수관계인 지분율 : 16.88
#
# 한국전력
# 최대주주 및 특수관계인 지분율 : 51.1
#
# LG
# 최대주주 및 특수관계인 지분율 : 46.07
#
# 삼성생명
# 최대주주 및 특수관계인 지분율 : 47.02
#
# SK아이이테크놀로지
# 최대주주 및 특수관계인 지분율 : 0
#
# 삼성전기
# 최대주주 및 특수관계인 지분율 : 23.69
#
# 엔씨소프트
# 최대주주 및 특수관계인 지분율 : 11.98
#
# 삼성에스디에스
# 최대주주 및 특수관계인 지분율 : 48.95
#
# 하나금융지주
# 최대주주 및 특수관계인 지분율 : 9.88
#
# 아모레퍼시픽
# 최대주주 및 특수관계인 지분율 : 37.38
#
# 포스코케미칼
# 최대주주 및 특수관계인 지분율 : 64.64
#
# KT&G
# 최대주주 및 특수관계인 지분율 : 11.52
#
# 하이브
# 최대주주 및 특수관계인 지분율 : 34.7
#
# 두산중공업
# 최대주주 및 특수관계인 지분율 : 42.47
#
# 대한항공
# 최대주주 및 특수관계인 지분율 : 29.27
#
# 넷마블
# 최대주주 및 특수관계인 지분율 : 24.15
#
# 삼성화재
# 최대주주 및 특수관계인 지분율 : 18.4
#
# S-Oil
# 최대주주 및 특수관계인 지분율 : 63.41
#
# 고려아연
# 최대주주 및 특수관계인 지분율 : 27.49
#
# SK바이오팜
# 최대주주 및 특수관계인 지분율 : 75.0
#
# 한온시스템
# 최대주주 및 특수관계인 지분율 : 50.5
#
# KT
# 최대주주 및 특수관계인 지분율 : 11.68
#
# 롯데케미칼
# 최대주주 및 특수관계인 지분율 : 54.92
#
# 우리금융지주
# 최대주주 및 특수관계인 지분율 : 17.25
#
# 한국조선해양
# 최대주주 및 특수관계인 지분율 : 33.95
#
# 한화솔루션
# 최대주주 및 특수관계인 지분율 : 37.41
#
# 기업은행
# 최대주주 및 특수관계인 지분율 : 66.1
#
# LG디스플레이
# 최대주주 및 특수관계인 지분율 : 37.9
#
# 현대글로비스
# 최대주주 및 특수관계인 지분율 : 34.88
#
# 현대제철
# 최대주주 및 특수관계인 지분율 : 24.14
#
# CJ제일제당
# 최대주주 및 특수관계인 지분율 : 41.77
#
# LG유플러스
# 최대주주 및 특수관계인 지분율 : 37.66
#
# 금호석유
# 최대주주 및 특수관계인 지분율 : 10.0
#
# 강원랜드
# 최대주주 및 특수관계인 지분율 : 36.27
#
# 현대건설
# 최대주주 및 특수관계인 지분율 : 34.92
#
# 코웨이
# 최대주주 및 특수관계인 지분율 : 25.08
#
# 한국타이어앤테크놀로지
# 최대주주 및 특수관계인 지분율 : 31.31
#
# SKC
# 최대주주 및 특수관계인 지분율 : 40.7
#
# 미래에셋증권
# 최대주주 및 특수관계인 지분율 : 23.98
#
# LG이노텍
# 최대주주 및 특수관계인 지분율 : 40.79
#
# 현대중공업지주
# 최대주주 및 특수관계인 지분율 : 34.34
#
# 한국금융지주
# 최대주주 및 특수관계인 지분율 : 20.7
#
# 한미사이언스
# 최대주주 및 특수관계인 지분율 : 66.4
#
# 이마트
# 최대주주 및 특수관계인 지분율 : 18.56
#
# 오리온
# 최대주주 및 특수관계인 지분율 : 39.2
#
# 삼성엔지니어링
# 최대주주 및 특수관계인 지분율 : 20.63
#
# 아모레G
# 최대주주 및 특수관계인 지분율 : 56.95
#
# 녹십자
# 최대주주 및 특수관계인 지분율 : 50.06
#
# 유한양행
# 최대주주 및 특수관계인 지분율 : 15.61
#
# 한진칼
# 최대주주 및 특수관계인 지분율 : 22.82
#
# 두산밥캣
# 최대주주 및 특수관계인 지분율 : 51.05
#
# 삼성증권
# 최대주주 및 특수관계인 지분율 : 29.78
#
# DB손해보험
# 최대주주 및 특수관계인 지분율 : 18.1
#
# 쌍용C&E
# 최대주주 및 특수관계인 지분율 : 77.68
#
# 팬오션
# 최대주주 및 특수관계인 지분율 : 54.73
#
# 삼성카드
# 최대주주 및 특수관계인 지분율 : 71.86
#
# GS
# 최대주주 및 특수관계인 지분율 : 52.1
#
# 삼성중공업
# 최대주주 및 특수관계인 지분율 : 19.04
#
# KCC
# 최대주주 및 특수관계인 지분율 : 33.2
#
# GS건설
# 최대주주 및 특수관계인 지분율 : 24.01
#
# CJ대한통운
# 최대주주 및 특수관계인 지분율 : 40.16
#
# 한미약품
# 최대주주 및 특수관계인 지분율 : 41.39
#
# 롯데지주
# 최대주주 및 특수관계인 지분율 : 42.6
#
# 신풍제약
# 최대주주 및 특수관계인 지분율 : 28.2
#
# 메리츠증권
# 최대주주 및 특수관계인 지분율 : 47.98
#
# NH투자증권
# 최대주주 및 특수관계인 지분율 : 49.12
#
# 한국가스공사
# 최대주주 및 특수관계인 지분율 : 52.62
#
# 한화시스템
# 최대주주 및 특수관계인 지분율 : 62.43
#
# 두산퓨얼셀
# 최대주주 및 특수관계인 지분율 : 46.57
#
# 일진머티리얼즈
# 최대주주 및 특수관계인 지분율 : 53.37
#
# 호텔신라
# 최대주주 및 특수관계인 지분율 : 17.1
#
# 한솔케미칼
# 최대주주 및 특수관계인 지분율 : 14.94
#
# GS리테일
# 최대주주 및 특수관계인 지분율 : 65.75
#
# 씨에스윈드
# 최대주주 및 특수관계인 지분율 : 52.37
#
# OCI
# 최대주주 및 특수관계인 지분율 : 20.75
#
# SK케미칼
# 최대주주 및 특수관계인 지분율 : 35.17
#
# 키움증권
# 최대주주 및 특수관계인 지분율 : 44.97
#
# 대우건설
# 최대주주 및 특수관계인 지분율 : 50.76
#
# 한국항공우주
# 최대주주 및 특수관계인 지분율 : 26.41
#
# 롯데쇼핑
# 최대주주 및 특수관계인 지분율 : 51.65
#
# 효성티앤씨
# 최대주주 및 특수관계인 지분율 : 20.32
#
# CJ
# 최대주주 및 특수관계인 지분율 : 42.07
#
# 에스원
# 최대주주 및 특수관계인 지분율 : 25.65
#
# BGF리테일
# 최대주주 및 특수관계인 지분율 : 55.1
#
# 대우조선해양
# 최대주주 및 특수관계인 지분율 : 55.7
#
# 포스코인터내셔널
# 최대주주 및 특수관계인 지분율 : 62.9
#
# 현대로템
# 최대주주 및 특수관계인 지분율 : 33.77
#
# 동서
# 최대주주 및 특수관계인 지분율 : 67.36
#
# 만도
# 최대주주 및 특수관계인 지분율 : 30.25
#
# 한샘
# 최대주주 및 특수관계인 지분율 : 20.97
#
# 현대미포조선
# 최대주주 및 특수관계인 지분율 : 42.55
#
# 한화생명
# 최대주주 및 특수관계인 지분율 : 44.99
#
# 제일기획
# 최대주주 및 특수관계인 지분율 : 28.58
#
# 휠라홀딩스
# 최대주주 및 특수관계인 지분율 : 21.64
#
# 효성첨단소재
# 최대주주 및 특수관계인 지분율 : 21.2
#
# 신세계
# 최대주주 및 특수관계인 지분율 : 28.56
#
# 한화
# 최대주주 및 특수관계인 지분율 : 36.26
#
# DB하이텍
# 최대주주 및 특수관계인 지분율 : 17.2
#
# DL이앤씨
# 최대주주 및 특수관계인 지분율 : 0
#
# BNK금융지주
# 최대주주 및 특수관계인 지분율 : 13.5
#
# 한화에어로스페이스
# 최대주주 및 특수관계인 지분율 : 33.98
#
# 현대위아
# 최대주주 및 특수관계인 지분율 : 38.79
#
# 효성
# 최대주주 및 특수관계인 지분율 : 53.7
#
# 코오롱인더
# 최대주주 및 특수관계인 지분율 : 35.4
#
# 현대해상
# 최대주주 및 특수관계인 지분율 : 21.9
#
# 하이트진로
# 최대주주 및 특수관계인 지분율 : 51.22
#
# 대한전선
# 최대주주 및 특수관계인 지분율 : 54.94
#
# 대웅
# 최대주주 및 특수관계인 지분율 : 24.15
#
# 현대엘리베이
# 최대주주 및 특수관계인 지분율 : 10.6
#
# LS ELECTRIC
# 최대주주 및 특수관계인 지분율 : 48.25
#
# LS
# 최대주주 및 특수관계인 지분율 : 34.94
#
# 한전기술
# 최대주주 및 특수관계인 지분율 : 65.77
#
# 대웅제약
# 최대주주 및 특수관계인 지분율 : 45.07
#
# 현대백화점
# 최대주주 및 특수관계인 지분율 : 36.08
#
# 오뚜기
# 최대주주 및 특수관계인 지분율 : 44.06
#
# HDC현대산업개발
# 최대주주 및 특수관계인 지분율 : 41.48
#
# 동국제강
# 최대주주 및 특수관계인 지분율 : 26.16
#
# 롯데정밀화학
# 최대주주 및 특수관계인 지분율 : 31.13
#
# 영원무역
# 최대주주 및 특수관계인 지분율 : 50.73
#
# 농심
# 최대주주 및 특수관계인 지분율 : 45.48
#
# 아시아나항공
# 최대주주 및 특수관계인 지분율 : 30.77
#
# 한전KPS
# 최대주주 및 특수관계인 지분율 : 51.0
#
# 금호타이어
# 최대주주 및 특수관계인 지분율 : 45.0
#
# 후성
# 최대주주 및 특수관계인 지분율 : 23.09
#
# 녹십자홀딩스
# 최대주주 및 특수관계인 지분율 : 50.71
#
# 대한유화
# 최대주주 및 특수관계인 지분율 : 39.86
#
# DL
# 최대주주 및 특수관계인 지분율 : 23.11
#
# 한국앤컴퍼니
# 최대주주 및 특수관계인 지분율 : 73.89
#
# 코스맥스
# 최대주주 및 특수관계인 지분율 : 26.24
#
# 종근당
# 최대주주 및 특수관계인 지분율 : 28.4
#
# F&F홀딩스
# 최대주주 및 특수관계인 지분율 : 58.82
#
# KG동부제철
# 최대주주 및 특수관계인 지분율 : 39.97
#
# 두산
# 최대주주 및 특수관계인 지분율 : 43.65
#
# 동원시스템즈
# 최대주주 및 특수관계인 지분율 : 80.84
#
# 아이에스동서
# 최대주주 및 특수관계인 지분율 : 54.69
#
# 부광약품
# 최대주주 및 특수관계인 지분율 : 9.93
#
# 신세계인터내셔날
# 최대주주 및 특수관계인 지분율 : 60.9
#
# SK네트웍스
# 최대주주 및 특수관계인 지분율 : 39.14
#
# 영풍
# 최대주주 및 특수관계인 지분율 : 46.72
#
# 지누스
# 최대주주 및 특수관계인 지분율 : 38.1
#
# 롯데관광개발
# 최대주주 및 특수관계인 지분율 : 52.13
#
# 한올바이오파마
# 최대주주 및 특수관계인 지분율 : 30.8
#
# 롯데칠성
# 최대주주 및 특수관계인 지분율 : 62.79
#
# 휴켐스
# 최대주주 및 특수관계인 지분율 : 43.41
#
# 더블유게임즈
# 최대주주 및 특수관계인 지분율 : 40.27
#
# CJ CGV
# 최대주주 및 특수관계인 지분율 : 38.4
#
# 보령제약
# 최대주주 및 특수관계인 지분율 : 43.78
#
# 태광산업
# 최대주주 및 특수관계인 지분율 : 50.01
#
# LX인터내셔널
# 최대주주 및 특수관계인 지분율 : 26.28
#
# 세방전지
# 최대주주 및 특수관계인 지분율 : 41.53
#
# LIG넥스원
# 최대주주 및 특수관계인 지분율 : 47.05
#
# 한국콜마
# 최대주주 및 특수관계인 지분율 : 30.17
#
# 이노션
# 최대주주 및 특수관계인 지분율 : 19.69
#
# 현대홈쇼핑
# 최대주주 및 특수관계인 지분율 : 25.01
#
# 두산인프라코어
# 최대주주 및 특수관계인 지분율 : 34.97
#
# 쿠쿠홈시스
# 최대주주 및 특수관계인 지분율 : 73.6
#
# 한섬
# 최대주주 및 특수관계인 지분율 : 34.64
#
# 오리온홀딩스
# 최대주주 및 특수관계인 지분율 : 63.8
#
# 화승엔터프라이즈
# 최대주주 및 특수관계인 지분율 : 71.73
#
# SK디스커버리
# 최대주주 및 특수관계인 지분율 : 45.07
#
# 현대그린푸드
# 최대주주 및 특수관계인 지분율 : 38.4
#
# 동원산업
# 최대주주 및 특수관계인 지분율 : 63.3
#
# 영진약품
# 최대주주 및 특수관계인 지분율 : 52.45
#
# 삼양홀딩스
# 최대주주 및 특수관계인 지분율 : 38.73
#
# GKL
# 최대주주 및 특수관계인 지분율 : 51.0
#
# 한세실업
# 최대주주 및 특수관계인 지분율 : 56.66
#
# 풍산
# 최대주주 및 특수관계인 지분율 : 38.0
#
# LX하우시스
# 최대주주 및 특수관계인 지분율 : 30.07
#
# 넥센타이어
# 최대주주 및 특수관계인 지분율 : 44.25
#
# 롯데하이마트
# 최대주주 및 특수관계인 지분율 : 61.01
#
# 동원F&B
# 최대주주 및 특수관계인 지분율 : 74.38
#
# LX홀딩스
# 최대주주 및 특수관계인 지분율 : 0
#
# SNT모티브
# 최대주주 및 특수관계인 지분율 : 40.03
#
# 일양약품
# 최대주주 및 특수관계인 지분율 : 26.27
#
# 쿠쿠홀딩스
# 최대주주 및 특수관계인 지분율 : 67.7
#
# 대상
# 최대주주 및 특수관계인 지분율 : 43.1
#
# JW중외제약
# 최대주주 및 특수관계인 지분율 : 39.52
#
# 락앤락
# 최대주주 및 특수관계인 지분율 : 66.07
#
# 삼양식품
# 최대주주 및 특수관계인 지분율 : 44.41

# %%
xlsx['최대주주 지분율'] = pd.Series(data=ratio_list, dtype=str)
xlsx
# Out:
#      Unnamed: 0    종목코드      name      종가    대비   등락률     상장시가총액    code  \
# 0             0    5930      삼성전자   77400   800  1.04  462061169  126380
# 1             1     660    SK하이닉스  106000 -1000 -0.93   77168251  164779
# 2             2   35420     NAVER  451500 -1000 -0.22   74164923  266961
# 3             3   35720       카카오  154000 -2500 -1.60   68484900  258801
# 4             4  207940  삼성바이오로직스  951000     0  0.00   62922915  877059
# ..          ...     ...       ...     ...   ...   ...        ...     ...
# 195         195  192400     쿠쿠홀딩스   24150  -100 -0.41     858827  132354
# 196         196    1680        대상   25150  -100 -0.40     871398  121941
# 197         197    1060    JW중외제약   27500  -150 -0.54     592348  149947
# 198         198  115390       락앤락   11700   -50 -0.43     620189  561866
# 199         199    3230      삼양식품   83600  -100 -0.12     629760  126955
#
#      Unnamed: 8 최대주주 지분율
# 0           NaN    21.07
# 1           NaN    20.07
# 2           NaN    11.56
# 3           NaN    25.44
# 4           NaN    75.08
# ..          ...      ...
# 195         NaN     67.7
# 196         NaN     43.1
# 197         NaN    39.52
# 198         NaN    66.07
# 199         NaN    44.41
#
# [200 rows x 10 columns]

# %%
xlsx.to_excel('최대주주.xlsx')

# %%
# 개별 회사 점검
import pandas as pd
from pandas import DataFrame
import requests
import pprint

#특수 관계인 정리
relative_list = [
    "최대주주",
    "본인",
    "본인(최대주주)",
    "최대주주본인",
    "본인및특별관계자",
    "본인및특수관계인",
    "최대주주(본인)",
    "최대주주의최대주주",
    "특수",
    "특수관계",
    "특수관계인",
    "기타특수관계인",
    "최대주주의특별관계자",
    "최대주주의특수관계인",
    "최대주주의직계비속",
    "최대주주의친인척",
    "최대주주의혈족6촌",
    "최대주주의배우자",
    "최대주주의모",
    "최대주주의부",
    "최대주주의자",
    "최대주주의형제",
    "최대주주의매제",
    "최대주주의매",
    "최대주주의제",
    "최대주주의처", 
    "최대주주제의자",
    "최대주주매의자",
    "최대주주의兄",
    "최대주주의父",
    "자녀",
    "배우자",
    "형제자매",
    "친족",
    "친인척",
    "임원\n(친인척)"
    "혈족1촌", 
    "혈족2촌", 
    "혈족3촌", 
    "혈족5촌", 
    "6촌이내의혈족",
    "4촌이내의인척",
    "제",
    "매",
    "조카",
    "사위",
    "숙부",
    "자",
    "처",
    "계열회사",
    "계열사",
    "최대주주의특수관계법인",
    "최대주주의계열회사",
    "최대주주의계열비영리법인",
    "최대주주의계 비영리법인",
    "지배회사",
    "모회사",
    "대표이사"
]

#dart open api 인자
auth_key="2e915b536849f9c4f517c681d00833f8d83ac7ee" 
company_code=""


#excel 파일 읽기 (row : 200개)
xlsx = pd.read_excel('./corp_dataset.xlsx')
xlsx['largest shareholder'] = ''


#비율
trmend_posesn_stock_qota_rt = ''
for i in range(1):
    reprt_code = 11011
    
    print(company_name)
    company_code = '01524093'
    url = 'https://opendart.fss.or.kr/api/hyslrSttus.json?crtfc_key={}&corp_code={}&bsns_year=2020&reprt_code={}'.format(auth_key, company_code, reprt_code)
    res = requests.get(url)
    data = res.json()
#     print(data)
    if data['status'] == '013':
        print('data가 없습니다.')
        while reprt_code < 11015:
            reprt_code += 1
            url = 'https://opendart.fss.or.kr/api/hyslrSttus.json?crtfc_key={}&corp_code={}&bsns_year=2020&reprt_code={}'.format(auth_key, company_code, reprt_code)
            res = requests.get(url)
            data = res.json()
            if data['status'] != '013':
                print(data)
                break
                
    largest = 0
    if data.get('list'):
        share_list = data['list']
    #         pprint.pprint(share_list)
        print('')

        print(share_list[0]['corp_name'])
        for share in share_list:
            print(share)
            type = share['stock_knd'].replace(" ", "")
            type = type.replace("\n", "")
            print(type)
            if type == '보통주' or type == '보통주식' or type == '의결권있는주식' or type == '의결권이있는주식' or type == '의결권있는보통주' or type == '의결권있는주식(보통주)' or type == '보통주(의결권있음)':
                if share['trmend_posesn_stock_qota_rt'] == '-':
                    ratio = 0
                else:
                    ratio = float(share['trmend_posesn_stock_qota_rt'])

                relative = share.get('relate')
                print(relative)
                if relative:
                    relative = relative.replace(" ", "")
                    relative = relative.replace("\n", "")

                if relative in relative_list:
                    largest += ratio
    print(largest)
# Out:
# 삼성전자
# data가 없습니다.
# {'message': '정의되지 않은 오류가 발생하였습니다.', 'status': '900'}
# 0

# %%
# 개별 회사 점검 이사회
import pandas as pd
from pandas import DataFrame
import requests
import pprint


#dart open api 인자
auth_key="2e915b536849f9c4f517c681d00833f8d83ac7ee" 
company_code=""


#excel 파일 읽기 (row : 200개)
xlsx = pd.read_excel('./corp_dataset.xlsx')
xlsx['largest shareholder'] = ''


#비율
trmend_posesn_stock_qota_rt = ''
for i in range(1):
    reprt_code = 11011
    company_code = '00161693'
    url = 'https://opendart.fss.or.kr/api/exctvSttus.json?crtfc_key={}&corp_code={}&bsns_year=2020&reprt_code={}'.format(auth_key, company_code, reprt_code)
    res = requests.get(url)
    data = res.json()
#     print(data)
    if data['status'] == '013':
        print('data가 없습니다.')
        while reprt_code < 11015:
            reprt_code += 1
            url = 'https://opendart.fss.or.kr/api/hyslrSttus.json?crtfc_key={}&corp_code={}&bsns_year=2020&reprt_code={}'.format(auth_key, company_code, reprt_code)
            res = requests.get(url)
            data = res.json()
            if data['status'] != '013':
                print(data)
                break
    
    pprint.pprint(data)
# Out:
# {'list': [{'birth_ym': '1939년 05월',
#            'chrg_job': '경영전략,\nR&D',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '(주)한샘 창업\n2018년 3월 16일 재선임',
#            'main_career': '(주)한샘 창업\n현)한샘 대표이사 명예회장',
#            'mxmm_shrholdr_relate': '본인',
#            'nm': '조창걸',
#            'ofcps': '대표이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '2021년 03월 16일'},
#           {'birth_ym': '1964년 02월',
#            'chrg_job': '키친바흐사업본부장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '1990년 01월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '김덕신',
#            'ofcps': '전무',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1967년 04월',
#            'chrg_job': '기업문화실장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2019년 12월 입사',
#            'main_career': '전) 중앙일보 디지털실장',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '김준현',
#            'ofcps': '전무',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1967년 02월',
#            'chrg_job': 'INT사업본부장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '1999년 07월 입사',
#            'main_career': '전)현대전자',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '김용하',
#            'ofcps': '상무',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1967년 02월',
#            'chrg_job': '한샘연구소 \nUDM팀장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2015년 01월 입사',
#            'main_career': '전)현대건설\n'
#                           '전)아키반도시 건축연구원\n'
#                           '전)서울시립대학교\n'
#                           '전)국립강원대학교\n'
#                           '전)간삼파트너스',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '김동건',
#            'ofcps': '상무',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1972년 03월',
#            'chrg_job': '디자인실장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '1999년 03월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '김윤희',
#            'ofcps': '상무',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '여',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1966년 02월',
#            'chrg_job': '한샘연구소 UDM팀',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2017년 2월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '최원미',
#            'ofcps': '상무',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '여',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1973년 06월',
#            'chrg_job': '대외협력실장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2018년 01월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '이주영',
#            'ofcps': '상무',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1965년 03월',
#            'chrg_job': '정보화추진부서장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2015년 01월 입사',
#            'main_career': '전)(주)제이디소프트\n전)펀잇시앤시\n전)(주)올테크\n전)(주)삼성SDI',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '김수영',
#            'ofcps': '이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1968년 07월',
#            'chrg_job': '특판사업본부장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '1992년 03월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '송기룡',
#            'ofcps': '이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1968년 01월',
#            'chrg_job': 'C/S부서장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2004년 06월 입사',
#            'main_career': '전)(주)썬스타R&C\n전)(주)썬스타산업봉제기계\n전)(주)긴텍스코리아\n전)대우중공업',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '이승호',
#            'ofcps': '이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1966년 06월',
#            'chrg_job': '경영총괄',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '1995년 입사\n2019년 3월 22일 재선임',
#            'main_career': '전) 대한항공 법무실\n현) (주)한샘 대표이사 회장',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '강승수',
#            'ofcps': '대표이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '2022년 03월 22일'},
#           {'birth_ym': '1959년 10월',
#            'chrg_job': '생활환경기술연구소장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '1983년 08월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '김홍광',
#            'ofcps': '이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1968년 11월',
#            'chrg_job': 'INT지원부서장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2001년 03월 입사',
#            'main_career': '전)금호건설\n전)컨스토피아',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '김광춘',
#            'ofcps': '이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1969년 09월',
#            'chrg_job': '온라인사업본부장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2009년 11월 입사',
#            'main_career': '전)SK커뮤니케이션즈\n전)삼일회계법인\n전)대림I&S',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '김태욱',
#            'ofcps': '이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1968년 11월',
#            'chrg_job': 'O2O지원부서장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '1994년 05월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '김종필',
#            'ofcps': '이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1965년 03월',
#            'chrg_job': '건재상품부서장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '1990년 11월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '장우순',
#            'ofcps': '이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1968년 02월',
#            'chrg_job': '중국사업TFT',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '1992년 07월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '이창욱',
#            'ofcps': '이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1973년 08월',
#            'chrg_job': '걍영기획부서장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2006년 6월 입사',
#            'main_career': '전)(주)한샘\n전)델 컴퓨터',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '손영동',
#            'ofcps': '이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1965년 12월',
#            'chrg_job': '중국시장조사TFT',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2016년 4월 입사',
#            'main_career': '전)GS건설\n전)도울건축\n전)서울건축',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '박종학',
#            'ofcps': '이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1975년 10월',
#            'chrg_job': '인사운영부서장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2013년 10월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '김룡',
#            'ofcps': '이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1972년 12월',
#            'chrg_job': '전략기획실 투자관리부서장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2019년 11월 입사',
#            'main_career': '전)로티스\n전)현대건설',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '황인철',
#            'ofcps': '이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1959년 11월',
#            'chrg_job': '전략기획실장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '1996년 입사\n2019년 3월 22일 재선임',
#            'main_career': '전) 세동회계법인\n현) (주)한샘 부회장',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '이영식',
#            'ofcps': '부회장',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '2022년 03월 22일'},
#           {'birth_ym': '1972년 01월',
#            'chrg_job': 'INT구매부서장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2000년 02월 입사',
#            'main_career': '전)신일건업\n전)삼은개발\n전)케이투건설',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '이희철',
#            'ofcps': '이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1967년 03월',
#            'chrg_job': '소비자호보실장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '1989년 11월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '오상우',
#            'ofcps': '이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1976년 01월',
#            'chrg_job': '인재개발부장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2020년 9월 입사',
#            'main_career': '고려대학교 대학원(인사조직) 졸업\n'
#                           ' MIT 경영학 졸업\n'
#                           ' 전)현대캐피탈주식회사\n'
#                           ' 전)맥킨지인코포레이티드\n'
#                           ' 전)㈜휴먼컨설팅그룹\n'
#                           ' 전)머서코리아주식회사\n'
#                           ' 전)㈜엑스퍼트컨설팅',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '한소영',
#            'ofcps': '이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '여',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1965년 07월',
#            'chrg_job': '인사이드TFT',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2016년 5월 입사',
#            'main_career': '전)(주)동명건설\n전)(주)태영건설\n전)(주)신영\n전)(주)GS건설\n전)(주)동부건설',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '양성호',
#            'ofcps': '이사대우',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1975년 08월',
#            'chrg_job': '리하우스영업1부서장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2002년 1월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '김근서',
#            'ofcps': '이사대우',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1971년 06월',
#            'chrg_job': '통합물류사업부서장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '1993년 4월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '이향호',
#            'ofcps': '이사대우',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1969년 11월',
#            'chrg_job': '홈캐어부서장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '1994년 12월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '이헌관',
#            'ofcps': '이사대우',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1967년 05월',
#            'chrg_job': '대외협력팀장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2019년 01월 입사',
#            'main_career': '경기도 대변인 언론협력 담당관\n국회의원실 보좌관(4급)',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '이승기',
#            'ofcps': '이사대우',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1964년 08월',
#            'chrg_job': '미국시장조사TFT팀장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2019년 03월 입사',
#            'main_career': '전)(주)한샘\n전)(주)한빌건설',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '이동진',
#            'ofcps': '이사대우',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1972년 10월',
#            'chrg_job': '리하우스사업본부\nRH영업4부 부서장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '1999년 2월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '최봉규',
#            'ofcps': '이사대우',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1964년 02월',
#            'chrg_job': '리하우스사업본부장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '1990년 입사\n2019년 3월 22일 재선임',
#            'main_career': '현)한샘 부사장',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '안흥국',
#            'ofcps': '부사장',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '2022년 03월 22일'},
#           {'birth_ym': '1972년 07월',
#            'chrg_job': '제조사업부서장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '1999년 3월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '남윤호',
#            'ofcps': '이사대우',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1978년 03월',
#            'chrg_job': '침실상품부서장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2002년 3월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '최지연',
#            'ofcps': '이사대우',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '여',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1973년 05월',
#            'chrg_job': '전략기획실 경영지원부\n재무관리팀장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2010년 7월 입사',
#            'main_career': '전) 페닌슐라캐피탈\n전) 안진회계법인\n전) 안건회계법인',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '정윤환',
#            'ofcps': '이사대우',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1972년 02월',
#            'chrg_job': 'C/S기획팀장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '1990년 11월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '이영일',
#            'ofcps': '이사대우',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1973년 04월',
#            'chrg_job': '리모델링상품부서장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2017년 9월 입사',
#            'main_career': '전) GS건설㈜',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '유정연',
#            'ofcps': '이사대우',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '여',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1976년 10월',
#            'chrg_job': '한샘연구소 UDM팀',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2010년 5월 입사',
#            'main_career': '-',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '최희진',
#            'ofcps': '이사대우',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '여',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1955년 05월',
#            'chrg_job': '경영전반',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '비상근',
#            'hffc_pd': '2020년 3월 20일 재선임\n(2011년 신규선임)',
#            'main_career': '전)한국전자통신연구원(ETRI) 책임연구원 및 실장\n현)한국외국어대 정보통신공학과 명예교수',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '정일영',
#            'ofcps': '사외이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '2023년 03월 19일'},
#           {'birth_ym': '1959년 01월',
#            'chrg_job': '경영전반',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '비상근',
#            'hffc_pd': '2020년 3월 20일 신규선임',
#            'main_career': '전)삼성인력개발원 \n현)한국뉴욕주립대학교 석좌교수 및 교육개발원장',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '신태균',
#            'ofcps': '사외이사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '2023년 03월 19일'},
#           {'birth_ym': '1972년 12월',
#            'chrg_job': '감사',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2020년 3월 20일 재선임\n(2017년 신규선임)',
#            'main_career': '전)부산지방법원\n'
#                           '전)서울고등법원\n'
#                           '전)서울북부지방법원\n'
#                           '전)서울중앙지방법원\n'
#                           '전)인천지방법원\n'
#                           '전)창원지방법원',
#            'mxmm_shrholdr_relate': '최대주주의사위 ',
#            'nm': '임창훈',
#            'ofcps': '감사',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '2023년 03월 19일'},
#           {'birth_ym': '1961년 04월',
#            'chrg_job': '한샘연구소 시장조사\nTFT ',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2003년 01월 입사',
#            'main_career': '전)현대건설',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '최진호',
#            'ofcps': '부사장',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '미등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '-'},
#           {'birth_ym': '1970년 10월',
#            'chrg_job': '경영지원부서장',
#            'corp_cls': 'Y',
#            'corp_code': '00161693',
#            'corp_name': '한샘',
#            'fte_at': '상근',
#            'hffc_pd': '2020년 3월 20일\n신규선임',
#            'main_career': '전)한영회계법인',
#            'mxmm_shrholdr_relate': '-',
#            'nm': '최철진',
#            'ofcps': '전무',
#            'rcept_no': '20210319001191',
#            'rgist_exctv_at': '등기임원',
#            'sexdstn': '남',
#            'tenure_end_on': '2023년 03월 19일'}],
#  'message': '정상',
#  'status': '000'}
